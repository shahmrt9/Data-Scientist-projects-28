# %% [markdown]
# # HOUSING: PRICE PREDICTION

# %% [markdown]
# Problem Statement:
#
# Houses are one of the necessary need of each and every person around the globe and therefore housing and real estate
# market is one of the markets which is one of the major contributors in the world’s economy. It is a very large market
# and there are various companies working in the domain. Data science comes as a very important tool to solve problems
# in the domain to help the companies increase their overall revenue, profits, improving their marketing strategies and
# focusing on changing trends in house sales and purchases. Predictive modelling, Market mix modelling,
# recommendation systems are some of the machine learning techniques used for achieving the business goals for housing
# companies. Our problem is related to one such housing company.
# A US-based housing company named Surprise Housing has decided to enter the Australian market. The company uses
# data analytics to purchase houses at a price below their actual values and flip them at a higher price. For the same
# purpose, the company has collected a data set from the sale of houses in Australia. The data is provided in the CSV file
# below.
# The company is looking at prospective properties to buy houses to enter the market. You are required to build a model
# using Machine Learning in order to predict the actual value of the prospective properties and decide whether to invest
# in them or not. For this company wants to know:
# • Which variables are important to predict the price of variable?
# • How do these variables describe the price of the house

# %% [markdown]
# Business Goal:
#
# You are required to model the price of houses with the available independent variables. This model will then be used
# by the management to understand how exactly the prices vary with the variables. They can accordingly manipulate the
# strategy of the firm and concentrate on areas that will yield high returns. Further, the model will be a good way for the
# management to understand the pricing dynamics of a new market.

# %% [markdown]
# Technical Requirements:
#
# • Data contains 1460 entries each having 81 variables.
# • Data contains Null values. You need to treat them using the domain knowledge and your own understanding.
# • Extensive EDA has to be performed to gain relationships of important variable and price.
# • Data contains numerical as well as categorical variable. You need to handle them accordingly.
# • You have to build Machine Learning models, apply regularization and determine the optimal values of Hyper
# Parameters.
# • You need to find important features which affect the price positively or negatively.
# • Two datasets are being provided to you (test.csv, train.csv). You will train on train.csv dataset and predict on
# test.csv file.

# %%
import pandas as pd        # for data manipulation
import numpy as np         # for mathematical calculations
import seaborn as sns      # for data visualization

import matplotlib.pyplot as plt  #for graphical analysis
# %matplotlib inline

from scipy.stats import zscore # to remove outliers

from sklearn.preprocessing import StandardScaler  # for normalize the model
from sklearn.preprocessing import LabelEncoder  # to convert object into int


from sklearn.model_selection import train_test_split  # for train and test model

import warnings                      # to ignore any warnings
warnings.filterwarnings("ignore")

from sklearn import metrics  # for model evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Load Dataset

# %%
data=pd.read_csv('train.csv')  # read the data
data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2007        WD         Normal     128000
# 1        10   2007        WD         Normal     268000
# 2         6   2007        WD         Normal     269790
# 3         1   2010       COD         Normal     190000
# 4         6   2009        WD         Normal     215000
# ...     ...    ...       ...            ...        ...
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [1168 rows x 81 columns]

# %% [markdown]
# # Dimensions of Dataset

# %%
# check the no. of rows & column & finding the count of missing value
print(data.shape)
print("-"*60)
print(data.isna().sum())
#printing the summary of data type
data.info()
# Out:
# (1168, 81)
# ------------------------------------------------------------
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1161 non-null   object
#  26  MasVnrArea     1161 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1168 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    617 non-null    object
#  58  GarageType     1104 non-null   object
#  59  GarageYrBlt    1104 non-null   float64
#  60  GarageFinish   1104 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1104 non-null   object
#  64  GarageCond     1104 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          237 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
#  80  SalePrice      1168 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 739.2+ KB

# %% [markdown]
# As we see there are null values are present in the train dataset.

# %%
#first remove duplicates & recheck the size
data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (1168, 81)

# %% [markdown]
# No duplicates are found so lets move further.

# %%
# Lest drop the irrelavent columns first 
data=data.drop(columns='Id', axis=1)

print(data.shape)
# Out:
# (1168, 80)

# %% [markdown]
# # Statistical Summary

# %%
# Lets understand data at high level check the stastics of dataset
data.describe(include='all')
# Out:
#          MSSubClass MSZoning  LotFrontage        LotArea Street Alley  \
# count   1168.000000     1168    954.00000    1168.000000   1168    77
# unique          NaN        5          NaN            NaN      2     2
# top             NaN       RL          NaN            NaN   Pave  Grvl
# freq            NaN      928          NaN            NaN   1164    41
# mean      56.767979      NaN     70.98847   10484.749144    NaN   NaN
# std       41.940650      NaN     24.82875    8957.442311    NaN   NaN
# min       20.000000      NaN     21.00000    1300.000000    NaN   NaN
# 25%       20.000000      NaN     60.00000    7621.500000    NaN   NaN
# 50%       50.000000      NaN     70.00000    9522.500000    NaN   NaN
# 75%       70.000000      NaN     80.00000   11515.500000    NaN   NaN
# max      190.000000      NaN    313.00000  164660.000000    NaN   NaN
#
#        LotShape LandContour Utilities LotConfig  ...     PoolArea PoolQC  \
# count      1168        1168      1168      1168  ...  1168.000000      7
# unique        4           4         1         5  ...          NaN      3
# top         Reg         Lvl    AllPub    Inside  ...          NaN     Gd
# freq        740        1046      1168       842  ...          NaN      3
# mean        NaN         NaN       NaN       NaN  ...     3.448630    NaN
# std         NaN         NaN       NaN       NaN  ...    44.896939    NaN
# min         NaN         NaN       NaN       NaN  ...     0.000000    NaN
# 25%         NaN         NaN       NaN       NaN  ...     0.000000    NaN
# 50%         NaN         NaN       NaN       NaN  ...     0.000000    NaN
# 75%         NaN         NaN       NaN       NaN  ...     0.000000    NaN
# max         NaN         NaN       NaN       NaN  ...   738.000000    NaN
#
#         Fence MiscFeature       MiscVal       MoSold       YrSold  SaleType  \
# count     237          44   1168.000000  1168.000000  1168.000000      1168
# unique      4           4           NaN          NaN          NaN         9
# top     MnPrv        Shed           NaN          NaN          NaN        WD
# freq      129          40           NaN          NaN          NaN       999
# mean      NaN         NaN     47.315068     6.344178  2007.804795       NaN
# std       NaN         NaN    543.264432     2.686352     1.329738       NaN
# min       NaN         NaN      0.000000     1.000000  2006.000000       NaN
# 25%       NaN         NaN      0.000000     5.000000  2007.000000       NaN
# 50%       NaN         NaN      0.000000     6.000000  2008.000000       NaN
# 75%       NaN         NaN      0.000000     8.000000  2009.000000       NaN
# max       NaN         NaN  15500.000000    12.000000  2010.000000       NaN
#
#         SaleCondition      SalePrice
# count            1168    1168.000000
# unique              6            NaN
# top            Normal            NaN
# freq              945            NaN
# mean              NaN  181477.005993
# std               NaN   79105.586863
# min               NaN   34900.000000
# 25%               NaN  130375.000000
# 50%               NaN  163995.000000
# 75%               NaN  215000.000000
# max               NaN  755000.000000
#
# [11 rows x 80 columns]

# %% [markdown]
# Observations: 1) null vallues are present 2)we have categorical data type(object type) 3)outliers are present in the dataset 4)in some columns thre is too much diffrance between mean and std. deviation

# %% [markdown]
# # EDA

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Plots

# %%
#plot each class frequency
sns.countplot(x='MSSubClass',data=data)
plt.show()
print(data['MSSubClass'].value_counts())
# Out:
# 20     428
# 60     244
# 50     113
# 120     69
# 70      53
# 30      52
# 160     47
# 80      43
# 90      41
# 190     26
# 85      19
# 75      14
# 45      10
# 180      6
# 40       3
# Name: MSSubClass, dtype: int64

# %% [markdown]
# From graph we cansee the type 20 MSSubClass of dwelling involved in the sale is more than the other and that is 428. The least MSSubClass of dwelling involved in the sale is 40 almost 3.

# %%
#plot each class frequency
sns.countplot(x='MSZoning',data=data)
plt.show()
print(data['MSZoning'].value_counts())
# Out:
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64

# %% [markdown]
# Residential Low Density is the most important general zoning classification of the sale than the others.

# %%
#plot each class frequency
plt.figure(figsize=(15,8))
sns.countplot(x='LotFrontage',data=data)
plt.show()
print(data['LotFrontage'].value_counts())
# Out:
# 60.0     111
# 80.0      60
# 70.0      58
# 75.0      46
# 50.0      44
#         ...
# 141.0      1
# 144.0      1
# 111.0      1
# 39.0       1
# 46.0       1
# Name: LotFrontage, Length: 106, dtype: int64

# %% [markdown]
# The  maximum 60 Linear feet of street connected to property.

# %%
#plot each class frequency
plt.figure(figsize=(15,8))
sns.countplot(x='SalePrice',data=data)
plt.show()
print(data['SalePrice'].value_counts())
# Out:
# 140000    18
# 135000    16
# 155000    12
# 160000    11
# 139000    11
#           ..
# 103600     1
# 238000     1
# 185500     1
# 132250     1
# 176485     1
# Name: SalePrice, Length: 581, dtype: int64

# %% [markdown]
# The Maximum sale price of the house is 140000

# %%
#plot each class frequency
plt.figure(figsize=(5,10))
sns.boxplot(y='LotArea',data=data)
plt.show()
print(data['LotArea'].value_counts())
# Out:
# 9600     21
# 7200     18
# 6000     16
# 8400     14
# 10800    11
#          ..
# 11103     1
# 19296     1
# 12274     1
# 9060      1
# 8190      1
# Name: LotArea, Length: 892, dtype: int64

# %% [markdown]
# From graph we can see the 9600 is the maximum Lot size in square feet. Also the outliers are present in this predictor.

# %%
#plot each class frequency
sns.countplot(x='Street',data=data)
plt.show()
print(data['Street'].value_counts())
# Out:
# Pave    1164
# Grvl       4
# Name: Street, dtype: int64

# %% [markdown]
# We can see the more Pave type of road properties are there to access the property.

# %%
#plot each class frequency
sns.countplot(x='Alley',data=data)
plt.show()
print(data['Alley'].value_counts())
# Out:
# Grvl    41
# Pave    36
# Name: Alley, dtype: int64

# %% [markdown]
# Both the type of properties has alley access to property.

# %%
#plot each class frequency
sns.countplot(x='LotShape',data=data)
plt.show()
print(data['LotShape'].value_counts())
# Out:
# Reg    740
# IR1    390
# IR2     32
# IR3      6
# Name: LotShape, dtype: int64

# %% [markdown]
# The maximum General shape of property is Regular then IR1 and the least shape of properties is IR3.

# %%
#plot each class frequency
sns.countplot(x='BldgType',data=data)
plt.show()
print(data['BldgType'].value_counts())
# Out:
# 1Fam      981
# TwnhsE     90
# Duplex     41
# Twnhs      29
# 2fmCon     27
# Name: BldgType, dtype: int64

# %% [markdown]
# From graph we can see that the maximum Type of dwelling in property is Single-family Detached

# %%
#plot each class frequency
sns.countplot(x='HouseStyle',data=data)
plt.show()
print(data['HouseStyle'].value_counts())
# Out:
# 1Story    578
# 2Story    361
# 1.5Fin    121
# SLvl       47
# SFoyer     32
# 1.5Unf     12
# 2.5Unf     10
# 2.5Fin      7
# Name: HouseStyle, dtype: int64

# %% [markdown]
# The more Style of dwelling preferd is 1story that is One story

# %%
#plot each class frequency
sns.countplot(x='OverallQual',data=data)
plt.show()
print(data['OverallQual'].value_counts())
# Out:
# 5     314
# 6     295
# 7     260
# 8     138
# 4      93
# 9      32
# 3      16
# 10     15
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %% [markdown]
# Rates the overall material and finish of the house are given  in as Average, Above Average, Good then Very Good. A very less cutomer has given 10 Very Excellent.

# %% [markdown]
# # Bivariate Plot

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='MSSubClass', y ='SalePrice', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# the maximum 2-STORY 1946 & NEWER the type of dwelling involved in the sale

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='MSZoning', y ='SalePrice', data = data, kind = "bar", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# The maximum sale price is for the Floating Village Residential and Residential Low Density

# %%
#Bivariant graph
plt.figure(figsize =(6, 6))
sns.catplot(x ='Street', y ='SalePrice', data = data, kind = "bar", height = 3, aspect = 3)
plt.show()

# %% [markdown]
# The sale price for the Pave type property is more than the Grvel.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='LotShape', y ='SalePrice', data = data, kind = "bar", height =3, aspect = 3)
plt.show()

# %% [markdown]
# The sale price is more for the Moderately Irregular type of property.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='MoSold', y ='SalePrice', data = data, kind = "bar", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# In the almost every month the propery was sale.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='SaleType', y ='SalePrice', data = data, kind = "bar", height = 3, aspect = 3)
plt.show()

# %% [markdown]
# The maximum type of sale property is Home just constructed and sold & Contract 15% Down payment regular terms.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='SaleCondition', y ='SalePrice', data = data, kind = "bar", height = 3, aspect = 3)
plt.show()

# %% [markdown]
#  From graph the maximum Condition of sale is Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# # Multivarieant plot

# %%
#check multicolinearity
plt.figure(figsize=(25,20))
sns.heatmap(data.corr(),annot=True,annot_kws={'size':12})
plt.show()

# %% [markdown]
# From above graph we can see that the relation with evry independet variable with target variable(positive) also in other independant variables. also we can see there are some colinarity present in some column. Further we will deal with it by using VIF.

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# As our dataset has the null value lets deal with it.

# %% [markdown]
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access

# %%
# As per the information in data description file the NA in the column Alley is No Alley Access so lets replace all NA with No alley access
data['Alley']=data['Alley'].replace("NA","No alley access")
data[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']]=data[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']].replace("NA","No Basement")
data['FireplaceQu']=data['FireplaceQu'].replace("NA","No Fireplace")
data['PoolQC']=data['PoolQC'].replace("NA","No Pool")
data['Fence']=data['Fence'].replace("NA","No Fence")
data[['GarageCond','GarageQual','GarageFinish','GarageType']]=data[['GarageCond','GarageQual','GarageFinish','GarageType']].replace("NA","No Garage")

# %%
# lets seaprate the catogorical data & numirical data
numerics=['int8','int16','int32','int64','float16','float32','float64']
cat_col=[] #empty list
features=data.columns.values.tolist()
for i in features:
    if data[i].dtype in numerics:
        continue
    cat_col.append(i)
cat_col
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
# Lets frist covert categorical data(type & column) into int 
label = LabelEncoder()
for i in cat_col:
    df=label.fit_transform(data[i])
    pd.Series(df)
    data[i]=df

# %% [markdown]
# As we have other null values also in the data set so lets deal with it by using Imputer tech.

# %% [markdown]
# Iterative Imputer
#
# Iterative imputer is a hidden gem of the sklearn library in python. The iterative imputer library provides us with tools to tackle the problem mentioned above. Instead of just replacing values with mean/median, we can have a regressor (Linear/Decision Tree/Random Forest/KNN) to impute missing values. By using the iterative imputer we can intelligently impute the missing values, avoid bias, maintain the relationship between variables, and can get better results.

# %%
# Creating null value list which we want to impute by using iterative inputer
df=data[['LotFrontage','MasVnrArea','GarageYrBlt','MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual',
 'ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer()

for i in df:
    df1=imputer.fit_transform(data[[i]])
    pd.Series([df1])
    data[i]=df1

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0         120       3.0     70.98847     4928     1.0    2.0       0.0
# 1          20       3.0     95.00000    15865     1.0    2.0       0.0
# 2          60       3.0     92.00000     9920     1.0    2.0       0.0
# 3          20       3.0    105.00000    11751     1.0    2.0       0.0
# 4          20       3.0     70.98847    16635     1.0    2.0       0.0
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0          3.0        0.0        4.0  ...         0     3.0    4.0
# 1          3.0        0.0        4.0  ...         0     3.0    4.0
# 2          3.0        0.0        1.0  ...         0     3.0    4.0
# 3          3.0        0.0        4.0  ...         0     3.0    2.0
# 4          3.0        0.0        2.0  ...         0     3.0    4.0
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          4.0        0       2    2007       8.0            4.0     128000
# 1          4.0        0      10    2007       8.0            4.0     268000
# 2          4.0        0       6    2007       8.0            4.0     269790
# 3          4.0        0       1    2010       0.0            4.0     190000
# 4          4.0        0       6    2009       8.0            4.0     215000
#
# [5 rows x 80 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 1167
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   float64
#  2   LotFrontage    1168 non-null   float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   float64
#  5   Alley          1168 non-null   float64
#  6   LotShape       1168 non-null   float64
#  7   LandContour    1168 non-null   float64
#  8   Utilities      1168 non-null   float64
#  9   LotConfig      1168 non-null   float64
#  10  LandSlope      1168 non-null   float64
#  11  Neighborhood   1168 non-null   float64
#  12  Condition1     1168 non-null   float64
#  13  Condition2     1168 non-null   float64
#  14  BldgType       1168 non-null   float64
#  15  HouseStyle     1168 non-null   float64
#  16  OverallQual    1168 non-null   int64
#  17  OverallCond    1168 non-null   int64
#  18  YearBuilt      1168 non-null   int64
#  19  YearRemodAdd   1168 non-null   int64
#  20  RoofStyle      1168 non-null   float64
#  21  RoofMatl       1168 non-null   float64
#  22  Exterior1st    1168 non-null   float64
#  23  Exterior2nd    1168 non-null   float64
#  24  MasVnrType     1168 non-null   float64
#  25  MasVnrArea     1168 non-null   float64
#  26  ExterQual      1168 non-null   float64
#  27  ExterCond      1168 non-null   float64
#  28  Foundation     1168 non-null   float64
#  29  BsmtQual       1168 non-null   float64
#  30  BsmtCond       1168 non-null   float64
#  31  BsmtExposure   1168 non-null   float64
#  32  BsmtFinType1   1168 non-null   float64
#  33  BsmtFinSF1     1168 non-null   int64
#  34  BsmtFinType2   1168 non-null   float64
#  35  BsmtFinSF2     1168 non-null   int64
#  36  BsmtUnfSF      1168 non-null   int64
#  37  TotalBsmtSF    1168 non-null   int64
#  38  Heating        1168 non-null   float64
#  39  HeatingQC      1168 non-null   float64
#  40  CentralAir     1168 non-null   float64
#  41  Electrical     1168 non-null   float64
#  42  1stFlrSF       1168 non-null   int64
#  43  2ndFlrSF       1168 non-null   int64
#  44  LowQualFinSF   1168 non-null   int64
#  45  GrLivArea      1168 non-null   int64
#  46  BsmtFullBath   1168 non-null   int64
#  47  BsmtHalfBath   1168 non-null   int64
#  48  FullBath       1168 non-null   int64
#  49  HalfBath       1168 non-null   int64
#  50  BedroomAbvGr   1168 non-null   int64
#  51  KitchenAbvGr   1168 non-null   int64
#  52  KitchenQual    1168 non-null   float64
#  53  TotRmsAbvGrd   1168 non-null   int64
#  54  Functional     1168 non-null   float64
#  55  Fireplaces     1168 non-null   int64
#  56  FireplaceQu    1168 non-null   float64
#  57  GarageType     1168 non-null   float64
#  58  GarageYrBlt    1168 non-null   float64
#  59  GarageFinish   1168 non-null   float64
#  60  GarageCars     1168 non-null   int64
#  61  GarageArea     1168 non-null   int64
#  62  GarageQual     1168 non-null   float64
#  63  GarageCond     1168 non-null   float64
#  64  PavedDrive     1168 non-null   float64
#  65  WoodDeckSF     1168 non-null   int64
#  66  OpenPorchSF    1168 non-null   int64
#  67  EnclosedPorch  1168 non-null   int64
#  68  3SsnPorch      1168 non-null   int64
#  69  ScreenPorch    1168 non-null   int64
#  70  PoolArea       1168 non-null   int64
#  71  PoolQC         1168 non-null   float64
#  72  Fence          1168 non-null   float64
#  73  MiscFeature    1168 non-null   float64
#  74  MiscVal        1168 non-null   int64
#  75  MoSold         1168 non-null   int64
#  76  YrSold         1168 non-null   int64
#  77  SaleType       1168 non-null   float64
#  78  SaleCondition  1168 non-null   float64
#  79  SalePrice      1168 non-null   int64
# dtypes: float64(46), int64(34)
# memory usage: 771.4 KB

# %% [markdown]
# As null values are treated well

# %%
# See again Statistical Summary
# Lets understand data at high level check the stastics of dataset
data.describe(include='all')
# Out:
#         MSSubClass     MSZoning  LotFrontage        LotArea       Street  \
# count  1168.000000  1168.000000  1168.000000    1168.000000  1168.000000
# mean     56.767979     3.013699    70.988470   10484.749144     0.996575
# std      41.940650     0.633120    22.437056    8957.442311     0.058445
# min      20.000000     0.000000    21.000000    1300.000000     0.000000
# 25%      20.000000     3.000000    60.000000    7621.500000     1.000000
# 50%      50.000000     3.000000    70.988470    9522.500000     1.000000
# 75%      70.000000     3.000000    79.250000   11515.500000     1.000000
# max     190.000000     4.000000   313.000000  164660.000000     1.000000
#
#              Alley     LotShape  LandContour  Utilities    LotConfig  ...  \
# count  1168.000000  1168.000000  1168.000000     1168.0  1168.000000  ...
# mean      1.898973     1.938356     2.773973        0.0     3.004281  ...
# std       0.401453     1.412262     0.710027        0.0     1.642667  ...
# min       0.000000     0.000000     0.000000        0.0     0.000000  ...
# 25%       2.000000     0.000000     3.000000        0.0     2.000000  ...
# 50%       2.000000     3.000000     3.000000        0.0     4.000000  ...
# 75%       2.000000     3.000000     3.000000        0.0     4.000000  ...
# max       2.000000     3.000000     3.000000        0.0     4.000000  ...
#
#           PoolArea       PoolQC        Fence  MiscFeature       MiscVal  \
# count  1168.000000  1168.000000  1168.000000  1168.000000   1168.000000
# mean      3.448630     2.988870     3.475171     3.921233     47.315068
# std      44.896939     0.157245     1.112090     0.408514    543.264432
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.000000     3.000000     4.000000     4.000000      0.000000
# 50%       0.000000     3.000000     4.000000     4.000000      0.000000
# 75%       0.000000     3.000000     4.000000     4.000000      0.000000
# max     738.000000     3.000000     4.000000     4.000000  15500.000000
#
#             MoSold       YrSold     SaleType  SaleCondition      SalePrice
# count  1168.000000  1168.000000  1168.000000    1168.000000    1168.000000
# mean      6.344178  2007.804795     7.465753       3.768836  181477.005993
# std       2.686352     1.329738     1.619459       1.112208   79105.586863
# min       1.000000  2006.000000     0.000000       0.000000   34900.000000
# 25%       5.000000  2007.000000     8.000000       4.000000  130375.000000
# 50%       6.000000  2008.000000     8.000000       4.000000  163995.000000
# 75%       8.000000  2009.000000     8.000000       4.000000  215000.000000
# max      12.000000  2010.000000     8.000000       5.000000  755000.000000
#
# [8 rows x 80 columns]

# %% [markdown]
# All null values are treated well now lets move further for the skewness & colinarity

# %%
#Let's see the how data is distributed or Graphical analysis of all features
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=40:
        ax=plt.subplot(8,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From graph we can see there are skewness is present in almost all the columns so lets check with .skew() method

# %%
data.skew(axis=0)
# Out:
# MSSubClass        1.422019
# MSZoning         -1.796785
# LotFrontage       2.710383
# LotArea          10.659285
# Street          -17.021969
#                    ...
# MoSold            0.220979
# YrSold            0.115765
# SaleType         -3.660513
# SaleCondition    -2.671829
# SalePrice         1.953878
# Length: 80, dtype: float64

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# As we see the skewed data is present as per thumb rule +0.5/-0.5 weight lets work on right skewed data by using power transform

# %%
# Separate the skewed columns
df1=['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
       'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
       'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
       'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
       'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
       'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
       'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
       'SaleType', 'SaleCondition', 'SalePrice']

# Using power transformation to remove skewed data
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
data[df1]=pt.fit_transform(data[df1].values)

# %%
# Distribution or Graphical analysis after Power transformation
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=40:
        ax=plt.subplot(8,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Now we handaled skewed data lets check the outliers between label and predictors

# %%
data.shape
# Out:
# (1168, 80)

# %%
#Let's see the outliers in the dataset by using box plot or Graphical analysis of all features
myFig=plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=64:
        ax=plt.subplot(8,8,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From graph we can see the outliers are present columns so lets deal with it by using Zscore

# %%
# Separate the outliers columns
df1=['MSZoning', 'LotFrontage', 'LotArea','LandContour', 'LandSlope','Condition1', 'Condition2', 'BldgType', 'OverallQual', 'OverallCond', 'RoofStyle',
       'RoofMatl', 'MasVnrType','ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond','BsmtExposure', 'BsmtFinType2',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating','CentralAir', 'Electrical', '1stFlrSF', 'LowQualFinSF','GrLivArea',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd','Functional','GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
       'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch','ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
       'SaleType', 'SaleCondition', 'SalePrice']

# %%
# from above graph we see there is outliers in featurs Let's remove outliers from above columns by using Zscore
z_score=zscore(data[df1])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
data=data[filtering_entry]

# %%
data.shape
# Out:
# (619, 80)

# %%
#Let's see plot after removing outliers
myFig=plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=40:
        ax=plt.subplot(10,4,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Now we handaled outliers data lets check the colinarity between label and predictors

# %%
# Let's Seperate the data & visulize the relation between featurs & lable
x=data.drop(columns=['SalePrice'])
y=data['SalePrice']

# %%
# data stadardization
scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#check multicolinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["featurs"]=x.columns
print(vif)
# Out:
#          vif        featurs
# 0   9.456248     MSSubClass
# 1   1.725692       MSZoning
# 2   2.268559    LotFrontage
# 3   3.527018        LotArea
# 4   0.000000         Street
# ..       ...            ...
# 74       NaN        MiscVal
# 75  1.142510         MoSold
# 76  1.202151         YrSold
# 77  1.665228       SaleType
# 78  1.829983  SaleCondition
#
# [79 rows x 2 columns]

# %%
# Lets make thumb rule we can drop the columns if VIF values are more than the 10 pvalue
index=np.where(vif['vif']>10)
vif.loc[index]
# Out:
#           vif       featurs
# 18  16.825635     YearBuilt
# 34  28.202149  BsmtFinType2
# 35  29.100187    BsmtFinSF2
# 37  10.831835   TotalBsmtSF
# 42  20.155439      1stFlrSF
# 43  26.117573      2ndFlrSF
# 45  27.504631     GrLivArea
# 58  10.631115   GarageYrBlt

# %% [markdown]
# As we see the pvalues of above predictors is more than 10 so lets drop the same & reduce the colinarity.

# %%
# Let's Seperate the data again 
x=data.drop(columns=['SalePrice','BsmtFinType2','BsmtFinSF2','GrLivArea','2ndFlrSF'])
y=data['SalePrice']

# %%
print(x.shape)
print(y.shape)
# Out:
# (619, 75)
# (619,)

# %%
# data stadardization again
scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
# see how featurs r related to lable(Graphical Analysis)
plt.figure(figsize=(15,20))
plotnumber=1
for column in x:
    if plotnumber<=40:
        ax=plt.subplot(10,4,plotnumber)
        sns.lineplot(y,x[column])
    plotnumber+=1
plt.show()

# %%
# Lets select the proper random state to build best model by using LinearRegression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_train)
    pred=lr.predict(x_test)
    print(f"at random sate {i}, the training accuracy is:- {r2_score(y_train,y_pred)}")
    print(f"at random sate {i}, the testing accuracy is:- {r2_score(y_test,pred)}")
    print("\n")
# Out:
# at random sate 0, the training accuracy is:- 0.92427959759245
# at random sate 0, the testing accuracy is:- 0.8604299003089814
#
#
# at random sate 1, the training accuracy is:- 0.9228309840110662
# at random sate 1, the testing accuracy is:- 0.870557906197243
#
#
# at random sate 2, the training accuracy is:- 0.9137067516659421
# at random sate 2, the testing accuracy is:- 0.8833232043828896
#
#
# at random sate 3, the training accuracy is:- 0.9186410048186013
# at random sate 3, the testing accuracy is:- 0.8811864266287709
#
#
# at random sate 4, the training accuracy is:- 0.9025880139189997
# at random sate 4, the testing accuracy is:- 0.9138756222573371
#
#
# at random sate 5, the training accuracy is:- 0.9187028121738262
# at random sate 5, the testing accuracy is:- 0.8756045733347547
#
#
# at random sate 6, the training accuracy is:- 0.9197289672086497
# at random sate 6, the testing accuracy is:- 0.873021147299995
#
#
# at random sate 7, the training accuracy is:- 0.9208905125520865
# at random sate 7, the testing accuracy is:- 0.874256880144197
#
#
# at random sate 8, the training accuracy is:- 0.9098087543437883
# at random sate 8, the testing accuracy is:- 0.8988092531679949
#
#
# at random sate 9, the training accuracy is:- 0.9139456915364687
# at random sate 9, the testing accuracy is:- 0.8885055363214396
#
#
# at random sate 10, the training accuracy is:- 0.9207579850144297
# at random sate 10, the testing accuracy is:- 0.8655949767321401
#
#
# at random sate 11, the training accuracy is:- 0.9156715272007673
# at random sate 11, the testing accuracy is:- 0.8896753697744759
#
#
# at random sate 12, the training accuracy is:- 0.9288270002082349
# at random sate 12, the testing accuracy is:- 0.8464210909208227
#
#
# at random sate 13, the training accuracy is:- 0.9293558835520902
# at random sate 13, the testing accuracy is:- 0.8442417755544711
#
#
# at random sate 14, the training accuracy is:- 0.909786979488149
# at random sate 14, the testing accuracy is:- 0.9036344061260632
#
#
# at random sate 15, the training accuracy is:- 0.9228780858708259
# at random sate 15, the testing accuracy is:- 0.8533600157882553
#
#
# at random sate 16, the training accuracy is:- 0.9240441149207855
# at random sate 16, the testing accuracy is:- 0.8625616274280645
#
#
# at random sate 17, the training accuracy is:- 0.9253946146330759
# at random sate 17, the testing accuracy is:- 0.867254266548391
#
#
# at random sate 18, the training accuracy is:- 0.907445852250408
# at random sate 18, the testing accuracy is:- 0.9078764882822081
#
#
# at random sate 19, the training accuracy is:- 0.9131377690545193
# at random sate 19, the testing accuracy is:- 0.8949356024454017
#
#
# at random sate 20, the training accuracy is:- 0.9185670721922917
# at random sate 20, the testing accuracy is:- 0.8815069016747101
#
#
# at random sate 21, the training accuracy is:- 0.9086247082190715
# at random sate 21, the testing accuracy is:- 0.9031363305511739
#
#
# at random sate 22, the training accuracy is:- 0.9193847190060068
# at random sate 22, the testing accuracy is:- 0.864454562093738
#
#
# at random sate 23, the training accuracy is:- 0.9025434727062596
# at random sate 23, the testing accuracy is:- 0.9168342794806081
#
#
# at random sate 24, the training accuracy is:- 0.9119929824880707
# at random sate 24, the testing accuracy is:- 0.8812689154960286
#
#
# at random sate 25, the training accuracy is:- 0.908649633958738
# at random sate 25, the testing accuracy is:- 0.9021498495968063
#
#
# at random sate 26, the training accuracy is:- 0.9091118850871134
# at random sate 26, the testing accuracy is:- 0.8951261254884457
#
#
# at random sate 27, the training accuracy is:- 0.9150628566019391
# at random sate 27, the testing accuracy is:- 0.8867211855447148
#
#
# at random sate 28, the training accuracy is:- 0.9159293465109001
# at random sate 28, the testing accuracy is:- 0.8882734548071941
#
#
# at random sate 29, the training accuracy is:- 0.9259761345476242
# at random sate 29, the testing accuracy is:- 0.858315890044615
#
#
# at random sate 30, the training accuracy is:- 0.912572959003564
# at random sate 30, the testing accuracy is:- 0.8950866004112774
#
#
# at random sate 31, the training accuracy is:- 0.9201808038321418
# at random sate 31, the testing accuracy is:- 0.8707706062937611
#
#
# at random sate 32, the training accuracy is:- 0.9183461242052592
# at random sate 32, the testing accuracy is:- 0.8798146430645505
#
#
# at random sate 33, the training accuracy is:- 0.9295665145426654
# at random sate 33, the testing accuracy is:- 0.8628108314892103
#
#
# at random sate 34, the training accuracy is:- 0.927789277251207
# at random sate 34, the testing accuracy is:- 0.8534347494184105
#
#
# at random sate 35, the training accuracy is:- 0.914430081293955
# at random sate 35, the testing accuracy is:- 0.8816415247684056
#
#
# at random sate 36, the training accuracy is:- 0.9139852103823584
# at random sate 36, the testing accuracy is:- 0.8758300480962568
#
#
# at random sate 37, the training accuracy is:- 0.9260325910840598
# at random sate 37, the testing accuracy is:- 0.8541067023448229
#
#
# at random sate 38, the training accuracy is:- 0.9116063870705452
# at random sate 38, the testing accuracy is:- 0.8961037233862683
#
#
# at random sate 39, the training accuracy is:- 0.9104792190853066
# at random sate 39, the testing accuracy is:- 0.8885924310059957
#
#
# at random sate 40, the training accuracy is:- 0.910548674279186
# at random sate 40, the testing accuracy is:- 0.8955205153576163
#
#
# at random sate 41, the training accuracy is:- 0.9129661838923043
# at random sate 41, the testing accuracy is:- 0.8908754890451142
#
#
# at random sate 42, the training accuracy is:- 0.9163396433681525
# at random sate 42, the testing accuracy is:- 0.8785355993954105
#
#
# at random sate 43, the training accuracy is:- 0.9318129248600155
# at random sate 43, the testing accuracy is:- 0.8388867585788338
#
#
# at random sate 44, the training accuracy is:- 0.9152868705027938
# at random sate 44, the testing accuracy is:- 0.8857709968444429
#
#
# at random sate 45, the training accuracy is:- 0.9025076034097569
# at random sate 45, the testing accuracy is:- 0.9164550046040235
#
#
# at random sate 46, the training accuracy is:- 0.9186053824232755
# at random sate 46, the testing accuracy is:- 0.8815619090687015
#
#
# at random sate 47, the training accuracy is:- 0.9045445903967794
# at random sate 47, the testing accuracy is:- 0.9110279142799708
#
#
# at random sate 48, the training accuracy is:- 0.9080265444282746
# at random sate 48, the testing accuracy is:- 0.9033840257555055
#
#
# at random sate 49, the training accuracy is:- 0.9245823468929717
# at random sate 49, the testing accuracy is:- 0.858643244471555
#
#
# at random sate 50, the training accuracy is:- 0.9177502181169392
# at random sate 50, the testing accuracy is:- 0.8800118986582878
#
#
# at random sate 51, the training accuracy is:- 0.922637180035817
# at random sate 51, the testing accuracy is:- 0.8695402065163247
#
#
# at random sate 52, the training accuracy is:- 0.9203703092357985
# at random sate 52, the testing accuracy is:- 0.8645118105180517
#
#
# at random sate 53, the training accuracy is:- 0.9126701310822407
# at random sate 53, the testing accuracy is:- 0.8966190728537197
#
#
# at random sate 54, the training accuracy is:- 0.9149546895593358
# at random sate 54, the testing accuracy is:- 0.8867597068957224
#
#
# at random sate 55, the training accuracy is:- 0.918241792402573
# at random sate 55, the testing accuracy is:- 0.8726311976087828
#
#
# at random sate 56, the training accuracy is:- 0.9313292049938703
# at random sate 56, the testing accuracy is:- 0.8132510087807877
#
#
# at random sate 57, the training accuracy is:- 0.9272071687332177
# at random sate 57, the testing accuracy is:- 0.856525251999974
#
#
# at random sate 58, the training accuracy is:- 0.9080276081529983
# at random sate 58, the testing accuracy is:- 0.9056093871247141
#
#
# at random sate 59, the training accuracy is:- 0.9193177345958783
# at random sate 59, the testing accuracy is:- 0.8638505948054166
#
#
# at random sate 60, the training accuracy is:- 0.91379605990463
# at random sate 60, the testing accuracy is:- 0.8828434043628731
#
#
# at random sate 61, the training accuracy is:- 0.911132898941738
# at random sate 61, the testing accuracy is:- 0.8991584881162803
#
#
# at random sate 62, the training accuracy is:- 0.9243726114072458
# at random sate 62, the testing accuracy is:- 0.8655248554073005
#
#
# at random sate 63, the training accuracy is:- 0.9113437437064948
# at random sate 63, the testing accuracy is:- 0.889354131565907
#
#
# at random sate 64, the training accuracy is:- 0.928577119641723
# at random sate 64, the testing accuracy is:- 0.8426836903426262
#
#
# at random sate 65, the training accuracy is:- 0.91445108956993
# at random sate 65, the testing accuracy is:- 0.8821486737108293
#
#
# at random sate 66, the training accuracy is:- 0.9091047662650071
# at random sate 66, the testing accuracy is:- 0.90260109039245
#
#
# at random sate 67, the training accuracy is:- 0.9165514092726796
# at random sate 67, the testing accuracy is:- 0.8779858120750693
#
#
# at random sate 68, the training accuracy is:- 0.9299559362931858
# at random sate 68, the testing accuracy is:- 0.8444855394943389
#
#
# at random sate 69, the training accuracy is:- 0.9022802333051357
# at random sate 69, the testing accuracy is:- 0.9183527786088994
#
#
# at random sate 70, the training accuracy is:- 0.9057015032539759
# at random sate 70, the testing accuracy is:- 0.9114473852774249
#
#
# at random sate 71, the training accuracy is:- 0.9178995592170004
# at random sate 71, the testing accuracy is:- 0.8749550472628785
# at random sate 72, the training accuracy is:- 0.9183693159873324
# at random sate 72, the testing accuracy is:- 0.8614944030935909
#
#
# at random sate 73, the training accuracy is:- 0.9343653520763651
# at random sate 73, the testing accuracy is:- 0.8381633858309485
#
#
# at random sate 74, the training accuracy is:- 0.9091635518539254
# at random sate 74, the testing accuracy is:- 0.8978560977147259
#
#
# at random sate 75, the training accuracy is:- 0.9164858885318306
# at random sate 75, the testing accuracy is:- 0.8881117657784118
#
#
# at random sate 76, the training accuracy is:- 0.9167146370892625
# at random sate 76, the testing accuracy is:- 0.8761684775015919
#
#
# at random sate 77, the training accuracy is:- 0.9303595054266108
# at random sate 77, the testing accuracy is:- 0.8364070967619428
#
#
# at random sate 78, the training accuracy is:- 0.9283009172433596
# at random sate 78, the testing accuracy is:- 0.8480431481775406
#
#
# at random sate 79, the training accuracy is:- 0.905491013225456
# at random sate 79, the testing accuracy is:- 0.9091711259741698
#
#
# at random sate 80, the training accuracy is:- 0.9237767498627175
# at random sate 80, the testing accuracy is:- 0.8623452230248793
#
#
# at random sate 81, the training accuracy is:- 0.9117144631943116
# at random sate 81, the testing accuracy is:- 0.8903959732072353
#
#
# at random sate 82, the training accuracy is:- 0.9081108680628723
# at random sate 82, the testing accuracy is:- 0.9000482426775975
#
#
# at random sate 83, the training accuracy is:- 0.9185677348554232
# at random sate 83, the testing accuracy is:- 0.8664409052240265
#
#
# at random sate 84, the training accuracy is:- 0.9126624583659789
# at random sate 84, the testing accuracy is:- 0.8955957057699908
#
#
# at random sate 85, the training accuracy is:- 0.9208181097652512
# at random sate 85, the testing accuracy is:- 0.8653512264207883
#
#
# at random sate 86, the training accuracy is:- 0.9296571005612461
# at random sate 86, the testing accuracy is:- 0.8571532493904865
#
#
# at random sate 87, the training accuracy is:- 0.9244475819119449
# at random sate 87, the testing accuracy is:- 0.8516938982662169
#
#
# at random sate 88, the training accuracy is:- 0.9205995960661936
# at random sate 88, the testing accuracy is:- 0.8755804437433978
#
#
# at random sate 89, the training accuracy is:- 0.9115684481019403
# at random sate 89, the testing accuracy is:- 0.9007966006483623
#
#
# at random sate 90, the training accuracy is:- 0.9042362878901538
# at random sate 90, the testing accuracy is:- 0.9156022783373629
#
#
# at random sate 91, the training accuracy is:- 0.9091248000145468
# at random sate 91, the testing accuracy is:- 0.9004205154580591
#
#
# at random sate 92, the training accuracy is:- 0.9282345450993603
# at random sate 92, the testing accuracy is:- 0.8612534748151458
#
#
# at random sate 93, the training accuracy is:- 0.9187729025366819
# at random sate 93, the testing accuracy is:- 0.8701252885206461
#
#
# at random sate 94, the training accuracy is:- 0.9116340357179155
# at random sate 94, the testing accuracy is:- 0.8953761226899106
#
#
# at random sate 95, the training accuracy is:- 0.9221446604670206
# at random sate 95, the testing accuracy is:- 0.8686740007060507
#
#
# at random sate 96, the training accuracy is:- 0.9205267093302577
# at random sate 96, the testing accuracy is:- 0.8562127691845605
#
#
# at random sate 97, the training accuracy is:- 0.9170500724976617
# at random sate 97, the testing accuracy is:- 0.888441488669309
#
#
# at random sate 98, the training accuracy is:- 0.9063702603693066
# at random sate 98, the testing accuracy is:- 0.9100196928411157
#
#
# at random sate 99, the training accuracy is:- 0.9137978755135183
# at random sate 99, the testing accuracy is:- 0.8907577923579209

# %% [markdown]
# at 58 random state the score is almost similar so i am selecting the 58 random state to build the best models

# %%
#Lets Split data  again into train & test by using this random state
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=58)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (433, 75)
# (433,)
# (186, 75)
# (186,)

# %% [markdown]
# # Lets Build the model for pridiction of sales price

# %%
def print_score(model,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=model.predict(x_train)
        print("Train Report:",r2_score(y_train,y_pred))
    elif train==False:
        pred=model.predict(x_test)
        print("Test Report:",r2_score(y_test,pred))
        print("RMSE:",np.sqrt(mean_squared_error(y_test,pred)))
        print("MAE:",mean_absolute_error(y_test,pred))
        print("MSE:",mean_squared_error(y_test,pred))

# %%
#Below is a function to find the accuracy of each model on the basis of K-fold cross validation.

from sklearn.model_selection import cross_val_score
def model_accuracy(model,X_train=x_train,y_train=y_train):
    accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv =5)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
# Model no.1
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)

print_score(lr,x_train,x_test,y_train,y_test,train=True)
print_score(lr,x_train,x_test,y_train,y_test,train=False)
model_accuracy(lr)
# Out:
# Train Report: 0.9080276081529983
# Test Report: 0.9056093871247141
# RMSE: 0.2514498866075719
# MAE: 0.19281181814548082
# MSE: 0.06322704547496076
# Accuracy: 85.98 %
# Standard Deviation: 3.99 %

# %%
# Model no.2
from sklearn.linear_model import LinearRegression, Lasso, LassoCV

lcv=LassoCV(alphas=None,max_iter=10000,normalize=True)
lcv.fit(x_train,y_train)
alpha=lcv.alpha_
print(alpha)
Lasso_reg=Lasso(alpha).fit(x_train,y_train)

print_score(Lasso_reg,x_train,x_test,y_train,y_test,train=True)
print_score(Lasso_reg,x_train,x_test,y_train,y_test,train=False)
model_accuracy(Lasso_reg)
# Out:
# 0.0004869863116328419
# Train Report: 0.9079791547504575
# Test Report: 0.9060285419169292
# RMSE: 0.2508909661323906
# MAE: 0.19217707449440888
# MSE: 0.06294627688684437
# Accuracy: 86.16 %
# Standard Deviation: 4.05 %

# %%
# Model no.3
from sklearn.ensemble import RandomForestRegressor

rand_regressor= RandomForestRegressor()
rand_regressor.fit(x_train,y_train)

print_score(rand_regressor,x_train,x_test,y_train,y_test,train=True)
print_score(rand_regressor,x_train,x_test,y_train,y_test,train=False)
model_accuracy(rand_regressor)
# Out:
# Train Report: 0.9763639515432244
# Test Report: 0.8688353356347611
# RMSE: 0.29641178538100743
# MAE: 0.2243813261332307
# MSE: 0.0878599465127564
# Accuracy: 81.50 %
# Standard Deviation: 4.56 %

# %%
# Model no.3
from xgboost import XGBRegressor

xgb=XGBRegressor()
xgb.fit(x_train,y_train)

print_score(xgb,x_train,x_test,y_train,y_test,train=True)
print_score(xgb,x_train,x_test,y_train,y_test,train=False)
model_accuracy(xgb)
# Out:
# Train Report: 0.9999988777699308
# Test Report: 0.866975159506532
# RMSE: 0.29850624031898
# MAE: 0.22965790186721105
# MSE: 0.08910597550937263
# Accuracy: 80.38 %
# Standard Deviation: 4.12 %

# %%
#Model no.4
from sklearn.ensemble import HistGradientBoostingRegressor

gbdt=HistGradientBoostingRegressor()

gbdt.fit(x_train,y_train)

print_score(gbdt,x_train,x_test,y_train,y_test,train=True)
print_score(gbdt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(gbdt)
# Out:
# Train Report: 0.986284834190471
# Test Report: 0.8909983490646709
# RMSE: 0.2702113448903229
# MAE: 0.21280564525111753
# MSE: 0.07301417090743703
# Accuracy: 83.38 %
# Standard Deviation: 3.40 %

# %%
#Model no.5
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()

dt.fit(x_train,y_train)

print_score(dt,x_train,x_test,y_train,y_test,train=True)
print_score(dt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(dt)
# Out:
# Train Report: 1.0
# Test Report: 0.7027666658783476
# RMSE: 0.44620640259849315
# MAE: 0.319052518153771
# MSE: 0.19910015371988854
# Accuracy: 58.24 %
# Standard Deviation: 8.17 %

# %% [markdown]
# # Looking at accuracy i m selecting Lasso regression with Kfold cross validation method

# %%
#save model
import pickle
Filename='Finalized_model_Sales_price.pickle'
pickle.dump(Lasso_reg,open(Filename,'wb'))

# %%
# Now form selected model lets understand the feature_importances or which feature are important for the prediction
# get importance 
importance = Lasso_reg.coef_
# summarize feature importance
F_list=[]
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
    F_list.append(v>0)
# Out:
# Feature: 0, Score: 0.09935
# Feature: 1, Score: -0.02756
# Feature: 2, Score: 0.02920
# Feature: 3, Score: 0.12447
# Feature: 4, Score: 0.00000
# Feature: 5, Score: -0.02606
# Feature: 6, Score: 0.02161
# Feature: 7, Score: -0.01401
# Feature: 8, Score: 0.00000
# Feature: 9, Score: -0.00185
# Feature: 10, Score: 0.00000
# Feature: 11, Score: 0.01509
# Feature: 12, Score: 0.01277
# Feature: 13, Score: 0.00000
# Feature: 14, Score: -0.01697
# Feature: 15, Score: -0.01129
# Feature: 16, Score: 0.20574
# Feature: 17, Score: 0.10060
# Feature: 18, Score: 0.07114
# Feature: 19, Score: 0.05107
# Feature: 20, Score: 0.01635
# Feature: 21, Score: 0.00000
# Feature: 22, Score: 0.03453
# Feature: 23, Score: 0.00000
# Feature: 24, Score: 0.02853
# Feature: 25, Score: 0.03079
# Feature: 26, Score: 0.00615
# Feature: 27, Score: 0.01130
# Feature: 28, Score: 0.00392
# Feature: 29, Score: -0.00957
# Feature: 30, Score: 0.01186
# Feature: 31, Score: -0.00000
# Feature: 32, Score: -0.00491
# Feature: 33, Score: 0.04395
# Feature: 34, Score: -0.04202
# Feature: 35, Score: 0.18296
# Feature: 36, Score: 0.00000
# Feature: 37, Score: -0.01354
# Feature: 38, Score: 0.00000
# Feature: 39, Score: 0.00000
# Feature: 40, Score: 0.08576
# Feature: 41, Score: 0.00000
# Feature: 42, Score: 0.03038
# Feature: 43, Score: 0.00000
# Feature: 44, Score: 0.12671
# Feature: 45, Score: 0.10483
# Feature: 46, Score: 0.02210
# Feature: 47, Score: 0.00000
# Feature: 48, Score: -0.04883
# Feature: 49, Score: 0.07528
# Feature: 50, Score: 0.00000
# Feature: 51, Score: 0.02641
# Feature: 52, Score: -0.00055
# Feature: 53, Score: 0.01723
# Feature: 54, Score: -0.00000
# Feature: 55, Score: -0.03731
# Feature: 56, Score: 0.02064
# Feature: 57, Score: 0.01252
# Feature: 58, Score: 0.00908
# Feature: 59, Score: 0.00000
# Feature: 60, Score: 0.00000
# Feature: 61, Score: 0.01317
# Feature: 62, Score: -0.01071
# Feature: 63, Score: 0.00920
# Feature: 64, Score: 0.00000
# Feature: 65, Score: 0.00000
# Feature: 66, Score: 0.00000
# Feature: 67, Score: 0.00000
# Feature: 68, Score: 0.02127
# Feature: 69, Score: 0.00000
# Feature: 70, Score: 0.00000
# Feature: 71, Score: 0.02089
# Feature: 72, Score: -0.00229
# Feature: 73, Score: -0.00105
# Feature: 74, Score: 0.02318

# %%
# plot feature importance
plt.figure(figsize=(20,8))
sns.barplot([x for x in range(len(importance))], importance)
plt.xlabel("Features")
plt.ylabel("Score")
plt.title("Feature importances")
plt.show()

# %% [markdown]
# # Lets Predict the sales price for the test data by selected model

# %%
data1=pd.read_csv('test.csv')  # read the data
data1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0           HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3           Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# ..          ...       ...  ...         ...      ...    ...   ...         ...
# 287         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 288         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 289         Lvl    AllPub  ...           0        0    NaN   NaN        Shed
# 290         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 291         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2007        WD         Normal
# 1         0      8    2009       COD        Abnorml
# 2         0      6    2009        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      1    2008        WD         Normal
# ..      ...    ...     ...       ...            ...
# 287       0     10    2008        WD         Normal
# 288       0      2    2008        WD         Normal
# 289     700      3    2010        WD         Normal
# 290       0     10    2006        WD         Normal
# 291       0      6    2006        WD         Normal
#
# [292 rows x 80 columns]

# %%
# check the no. of rows & column & finding the count of missing value
print(data1.shape)
print("-"*60)
print(data1.isna().sum())
print("-"*60)
#printing the summary of data type
print(data1.info())

#first remove duplicates & recheck the size
data1.drop_duplicates(inplace=True)

# Lest drop the irrelavent columns first 
data1=data1.drop(columns='Id', axis=1)

print(data1.shape)
print("-"*60)
# Lets understand data at high level check the stastics of dataset
print(data1.describe(include='all'))
print("-"*60)

# As per the information in data description file the NA in the column Alley is No Alley Access so lets replace all NA with No alley access
data1['Alley']=data1['Alley'].replace("NA","No alley access")
data1[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']]=data1[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']].replace("NA","No Basement")
data1['FireplaceQu']=data1['FireplaceQu'].replace("NA","No Fireplace")
data1['PoolQC']=data1['PoolQC'].replace("NA","No Pool")
data1['Fence']=data1['Fence'].replace("NA","No Fence")
data1[['GarageCond','GarageQual','GarageFinish','GarageType']]=data1[['GarageCond','GarageQual','GarageFinish','GarageType']].replace("NA","No Garage")

# As we see in POOlQC column null values are present so lets fill with zeros
data1['PoolQC']=data1['PoolQC'].fillna(0)

# lets seaprate the catogorical data & numirical data
numerics=['int8','int16','int32','int64','float16','float32','float64']
cat_col=[] #empty list
features=data1.columns.values.tolist()
for i in features:
    if data1[i].dtype in numerics:
        continue
    cat_col.append(i)

    
# Lets frist covert categorical data(type & column) into int 
label = LabelEncoder()
for i in cat_col:
    df=label.fit_transform(data1[i])
    pd.Series(df)
    data1[i]=df
    
    
    
# Creating null value list which we want to impute by using iterative inputer
df=data1[['LotFrontage','MasVnrArea','GarageYrBlt','MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual',
 'ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolArea','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']]

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer()
for i in df:
    df1=imputer.fit_transform(data1[[i]])
    pd.Series([df1])
    data1[i]=df1

    
    
# Still null values are present so lets deal with it by using mean method
data1['LotFrontage']=data1['LotFrontage'].fillna(data1['LotFrontage'].mean())

# See again Statistical Summary
# Lets understand data at high level check the stastics of dataset
data1.describe(include='all')
# Out:
# (292, 80)
# ------------------------------------------------------------
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64
# ------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
#  17  OverallQual    292 non-null    int64
#  18  OverallCond    292 non-null    int64
#  19  YearBuilt      292 non-null    int64
#  20  YearRemodAdd   292 non-null    int64
#  21  RoofStyle      292 non-null    object
#  22  RoofMatl       292 non-null    object
#  23  Exterior1st    292 non-null    object
#  24  Exterior2nd    292 non-null    object
#  25  MasVnrType     291 non-null    object
#  26  MasVnrArea     291 non-null    float64
#  27  ExterQual      292 non-null    object
#  28  ExterCond      292 non-null    object
#  29  Foundation     292 non-null    object
#  30  BsmtQual       285 non-null    object
#  31  BsmtCond       285 non-null    object
#  32  BsmtExposure   285 non-null    object
#  33  BsmtFinType1   285 non-null    object
#  34  BsmtFinSF1     292 non-null    int64
#  35  BsmtFinType2   285 non-null    object
#  36  BsmtFinSF2     292 non-null    int64
#  37  BsmtUnfSF      292 non-null    int64
#  38  TotalBsmtSF    292 non-null    int64
#  39  Heating        292 non-null    object
#  40  HeatingQC      292 non-null    object
#  41  CentralAir     292 non-null    object
#  42  Electrical     291 non-null    object
#  43  1stFlrSF       292 non-null    int64
#  44  2ndFlrSF       292 non-null    int64
#  45  LowQualFinSF   292 non-null    int64
#  46  GrLivArea      292 non-null    int64
#  47  BsmtFullBath   292 non-null    int64
#  48  BsmtHalfBath   292 non-null    int64
#  49  FullBath       292 non-null    int64
#  50  HalfBath       292 non-null    int64
#  51  BedroomAbvGr   292 non-null    int64
#  52  KitchenAbvGr   292 non-null    int64
#  53  KitchenQual    292 non-null    object
#  54  TotRmsAbvGrd   292 non-null    int64
#  55  Functional     292 non-null    object
#  56  Fireplaces     292 non-null    int64
#  57  FireplaceQu    153 non-null    object
#  58  GarageType     275 non-null    object
#  59  GarageYrBlt    275 non-null    float64
#  60  GarageFinish   275 non-null    object
#  61  GarageCars     292 non-null    int64
#  62  GarageArea     292 non-null    int64
#  63  GarageQual     275 non-null    object
#  64  GarageCond     275 non-null    object
#  65  PavedDrive     292 non-null    object
#  66  WoodDeckSF     292 non-null    int64
#  67  OpenPorchSF    292 non-null    int64
#  68  EnclosedPorch  292 non-null    int64
#  69  3SsnPorch      292 non-null    int64
#  70  ScreenPorch    292 non-null    int64
#  71  PoolArea       292 non-null    int64
#  72  PoolQC         0 non-null      float64
#  73  Fence          44 non-null     object
#  74  MiscFeature    10 non-null     object
#  75  MiscVal        292 non-null    int64
#  76  MoSold         292 non-null    int64
#  77  YrSold         292 non-null    int64
#  78  SaleType       292 non-null    object
#  79  SaleCondition  292 non-null    object
# dtypes: float64(4), int64(34), object(42)
# memory usage: 182.6+ KB
# None
# (292, 79)
# ------------------------------------------------------------
#         MSSubClass MSZoning  LotFrontage        LotArea Street Alley LotShape  \
# count   292.000000      292   247.000000     292.000000    292    14      292
# unique         NaN        4          NaN            NaN      2     2        4
# top            NaN       RL          NaN            NaN   Pave  Grvl      Reg
# freq           NaN      223          NaN            NaN    290     9      185
# mean     57.414384      NaN    66.425101   10645.143836    NaN   NaN      NaN
# std      43.780649      NaN    21.726343   13330.669795    NaN   NaN      NaN
# min      20.000000      NaN    21.000000    1526.000000    NaN   NaN      NaN
# 25%      20.000000      NaN    53.500000    7200.000000    NaN   NaN      NaN
# 50%      50.000000      NaN    65.000000    9200.000000    NaN   NaN      NaN
# 75%      70.000000      NaN    79.000000   11658.750000    NaN   NaN      NaN
# max     190.000000      NaN   150.000000  215245.000000    NaN   NaN      NaN
#
#        LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  \
# count          292       292       292  ...  292.000000    292.0    0.0
# unique           4         2         5  ...         NaN      NaN    NaN
# top            Lvl    AllPub    Inside  ...         NaN      NaN    NaN
# freq           265       291       210  ...         NaN      NaN    NaN
# mean           NaN       NaN       NaN  ...   15.099315      0.0    NaN
# std            NaN       NaN       NaN  ...   58.483473      0.0    NaN
# min            NaN       NaN       NaN  ...    0.000000      0.0    NaN
# 25%            NaN       NaN       NaN  ...    0.000000      0.0    NaN
# 50%            NaN       NaN       NaN  ...    0.000000      0.0    NaN
# 75%            NaN       NaN       NaN  ...    0.000000      0.0    NaN
# max            NaN       NaN       NaN  ...  396.000000      0.0    NaN
#
#         Fence MiscFeature      MiscVal      MoSold       YrSold  SaleType  \
# count      44          10   292.000000  292.000000   292.000000       292
# unique      4           2          NaN         NaN          NaN         6
# top     MnPrv        Shed          NaN         NaN          NaN        WD
# freq       28           9          NaN         NaN          NaN       268
# mean      NaN         NaN    28.184932    6.232877  2007.859589       NaN
# std       NaN         NaN   224.036218    2.774556     1.322867       NaN
# min       NaN         NaN     0.000000    1.000000  2006.000000       NaN
# 25%       NaN         NaN     0.000000    4.000000  2007.000000       NaN
# 50%       NaN         NaN     0.000000    6.000000  2008.000000       NaN
# 75%       NaN         NaN     0.000000    8.000000  2009.000000       NaN
# max       NaN         NaN  3500.000000   12.000000  2010.000000       NaN
#
#         SaleCondition
# count             292
# unique              4
# top            Normal
# freq              253
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN
#
# [11 rows x 79 columns]
# ------------------------------------------------------------
#        MSSubClass    MSZoning  LotFrontage        LotArea      Street  \
# count  292.000000  292.000000   292.000000     292.000000  292.000000
# mean    57.414384    2.136986    66.425101   10645.143836    0.993151
# std     43.780649    0.478114    19.975962   13330.669795    0.082618
# min     20.000000    0.000000    21.000000    1526.000000    0.000000
# 25%     20.000000    2.000000    57.750000    7200.000000    1.000000
# 50%     50.000000    2.000000    66.425101    9200.000000    1.000000
# 75%     70.000000    2.000000    76.000000   11658.750000    1.000000
# max    190.000000    3.000000   150.000000  215245.000000    1.000000
#
#             Alley    LotShape  LandContour   Utilities   LotConfig  ...  \
# count  292.000000  292.000000   292.000000  292.000000  292.000000  ...
# mean     1.921233    1.958904     2.791096    0.003425    3.078767  ...
# std      0.366971    1.398953     0.699182    0.058521    1.541174  ...
# min      0.000000    0.000000     0.000000    0.000000    0.000000  ...
# 25%      2.000000    0.000000     3.000000    0.000000    2.000000  ...
# 50%      2.000000    3.000000     3.000000    0.000000    4.000000  ...
# 75%      2.000000    3.000000     3.000000    0.000000    4.000000  ...
# max      2.000000    3.000000     3.000000    1.000000    4.000000  ...
#
#        ScreenPorch  PoolArea  PoolQC       Fence  MiscFeature      MiscVal  \
# count   292.000000     292.0   292.0  292.000000   292.000000   292.000000
# mean     15.099315       0.0     0.0    3.623288     1.962329    28.184932
# std      58.483473       0.0     0.0    0.949881     0.207965   224.036218
# min       0.000000       0.0     0.0    0.000000     0.000000     0.000000
# 25%       0.000000       0.0     0.0    4.000000     2.000000     0.000000
# 50%       0.000000       0.0     0.0    4.000000     2.000000     0.000000
# 75%       0.000000       0.0     0.0    4.000000     2.000000     0.000000
# max     396.000000       0.0     0.0    4.000000     2.000000  3500.000000
#
#            MoSold       YrSold    SaleType  SaleCondition
# count  292.000000   292.000000  292.000000     292.000000
# mean     6.232877  2007.859589    4.828767       1.914384
# std      2.774556     1.322867    0.744829       0.576932
# min      1.000000  2006.000000    0.000000       0.000000
# 25%      4.000000  2007.000000    5.000000       2.000000
# 50%      6.000000  2008.000000    5.000000       2.000000
# 75%      8.000000  2009.000000    5.000000       2.000000
# max     12.000000  2010.000000    5.000000       3.000000
#
# [8 rows x 79 columns]

# %%
data1.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 79, dtype: int64

# %% [markdown]
# Null values treated well lets move further for the skewness.

# %%
data1.skew()
# Out:
# MSSubClass        1.358597
# MSZoning          0.187174
# LotFrontage       0.466813
# LotArea          12.781805
# Street          -12.020386
#                    ...
# MiscVal          13.264758
# MoSold            0.186504
# YrSold            0.018412
# SaleType         -5.489874
# SaleCondition    -2.161104
# Length: 79, dtype: float64

# %% [markdown]
# As we see the skewness is present in the columns lets remove by using power transformation

# %%
# Separate the skewed columns
df1=['MSSubClass','LotArea', 'Street', 'Alley',
       'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
       'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
       'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
       'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
       'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
       'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
       'SaleType', 'SaleCondition']

# Using power transformation to remove skewed data
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
data1[df1]=pt.fit_transform(data1[df1].values)

# %% [markdown]
# Now we handaled skewed data lets check the colinarity between label and predictors

# %%
data1.shape
# Out:
# (292, 79)

# %% [markdown]
# Based on feature importance lets select the features for the prediction

# %%
data1=data1.drop(columns=['EnclosedPorch','ScreenPorch','PoolArea','LandSlope'])
data1.shape
# Out:
# (292, 75)

# %% [markdown]
# # Lets Do the prediction by using selected saved model

# %%
data1["predictions"] = data1.apply(lambda s: Lasso_reg.predict(s.values[None])[0], axis=1)

# %%
data1["predictions"]
# Out:
# 0     -1.089465
# 1     -2.677371
# 2     -1.824881
# 3     -1.894500
# 4     -1.235600
#          ...
# 287   -1.347981
# 288   -2.850127
# 289   -2.235654
# 290   -2.550420
# 291   -4.375404
# Name: predictions, Length: 292, dtype: float64
