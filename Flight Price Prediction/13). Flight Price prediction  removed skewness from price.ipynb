# %%
import pandas as pd        # for data manipulation
import numpy as np         # for mathematical calculations
import seaborn as sns      # for data visualization

import matplotlib.pyplot as plt  #for graphical analysis
# %matplotlib inline

from scipy.stats import zscore # to remove outliers

from sklearn.preprocessing import StandardScaler  # for normalize the model
from sklearn.preprocessing import LabelEncoder  # to convert object into int


from sklearn.model_selection import train_test_split  # for train and test model

import warnings                      # to ignore any warnings
warnings.filterwarnings("ignore")

from sklearn import metrics  # for model evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Load Dataset

# %%
data=pd.read_csv('All_flights.csv')  # read the data
data
# Out:
#       Unnamed: 0.1  Unnamed: 0    Flight_Name Departure Departure_Place  \
# 0                0           0         IndiGo     15:10       New Delhi
# 1                1           1       Go First     05:45       New Delhi
# 2                2           2        Vistara     05:35       New Delhi
# 3                3           3         IndiGo     19:45       New Delhi
# 4                4           4         IndiGo     05:55       New Delhi
# ...            ...         ...            ...       ...             ...
# 1713          1713         145      AKASA AIR     20:50         Chennai
# 1714          1714         146         INDIGO     22:25         Chennai
# 1715          1715         147  AIRASIA INDIA     06:55         Chennai
# 1716          1716         148         INDIGO     08:30         Chennai
# 1717          1717         149         INDIGO     20:00         Chennai
#
#      Arrival Arrival_Destination           Total_Stops  \
# 0      00:05           Bengaluru  1 stop via Hyderabad
# 1      08:35           Bengaluru              Non stop
# 2      08:30           Bengaluru              Non stop
# 3      01:10           Bengaluru  1 stop via Hyderabad
# 4      08:45           Bengaluru              Non stop
# ...      ...                 ...                   ...
# 1713   22:50              Mumbai              non-stop
# 1714   00:20              Mumbai              non-stop
# 1715   21:00              Mumbai                1 stop
# 1716   10:20              Mumbai              non-stop
# 1717   21:55              Mumbai              non-stop
#
#                              Duration    Price
# 0     08 h 55 m\n1 stop via Hyderabad  ₹ 5,988
# 1                 02 h 50 m\nNon stop  ₹ 7,107
# 2                 02 h 55 m\nNon stop  ₹ 7,184
# 3     05 h 25 m\n1 stop via Hyderabad  ₹ 7,487
# 4                 02 h 50 m\nNon stop  ₹ 7,499
# ...                               ...      ...
# 1713                              2hr     2910
# 1714                        1hr 55min     2914
# 1715                        14hr 5min     3149
# 1716                        1hr 50min     3400
# 1717                        1hr 55min     3400
#
# [1718 rows x 10 columns]

# %% [markdown]
# # Dimensions of Dataset

# %%
# check the no. of rows & column & finding the count of missing value
print(data.shape)

print(data.isna().sum())

#printing the summary of data type
data.info()
# Out:
# (1718, 10)
# Unnamed: 0.1             0
# Unnamed: 0               0
# Flight_Name            102
# Departure                0
# Departure_Place         99
# Arrival                  0
# Arrival_Destination     46
# Total_Stops              0
# Duration                 0
# Price                    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0.1         1718 non-null   int64
#  1   Unnamed: 0           1718 non-null   int64
#  2   Flight_Name          1616 non-null   object
#  3   Departure            1718 non-null   object
#  4   Departure_Place      1619 non-null   object
#  5   Arrival              1718 non-null   object
#  6   Arrival_Destination  1672 non-null   object
#  7   Total_Stops          1718 non-null   object
#  8   Duration             1718 non-null   object
#  9   Price                1718 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 134.3+ KB

# %% [markdown]
# As we see the null values are present in the dataset.

# %%
# Drop unneccesary column
data=data.drop(columns=['Unnamed: 0.1','Unnamed: 0'],axis=1)

# %%
data.head(3)
# Out:
#   Flight_Name Departure Departure_Place Arrival Arrival_Destination  \
# 0      IndiGo     15:10       New Delhi   00:05           Bengaluru
# 1    Go First     05:45       New Delhi   08:35           Bengaluru
# 2     Vistara     05:35       New Delhi   08:30           Bengaluru
#
#             Total_Stops                         Duration    Price
# 0  1 stop via Hyderabad  08 h 55 m\n1 stop via Hyderabad  ₹ 5,988
# 1              Non stop              02 h 50 m\nNon stop  ₹ 7,107
# 2              Non stop              02 h 55 m\nNon stop  ₹ 7,184

# %%
#first remove duplicates & recheck the size
data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (1309, 8)

# %% [markdown]
# From above counting or shape we see there are duplicates are presents that we removed

# %% [markdown]
# # Statistical Summary

# %%
# Lets understand data at high level check the stastics of dataset
data.describe()
# Out:
#        Flight_Name Departure Departure_Place Arrival Arrival_Destination  \
# count         1215      1309            1218    1309                1265
# unique          42       240               6     291                  21
# top        Vistara     07:10       Hyderabad   21:20           New Delhi
# freq           252        48             334      40                 375
#
#        Total_Stops Duration   Price
# count         1309     1309    1309
# unique          15      424     511
# top         1 Stop   2h 15m  ₹15078
# freq           614       33      38

# %% [markdown]
# Observations: 1) null vallues are present 2)we have categorical data type(object type)

# %% [markdown]
# # EDA

# %% [markdown]
# # Data Pre-Processing

# %%
#Converting all capital letter into small letters
for i in data:
    data[i] =data[i].str.lower()
data
# Out:
#         Flight_Name Departure Departure_Place Arrival Arrival_Destination  \
# 0            indigo     15:10       new delhi   00:05           bengaluru
# 1          go first     05:45       new delhi   08:35           bengaluru
# 2           vistara     05:35       new delhi   08:30           bengaluru
# 3            indigo     19:45       new delhi   01:10           bengaluru
# 4            indigo     05:55       new delhi   08:45           bengaluru
# ...             ...       ...             ...     ...                 ...
# 1593      akasa air     20:50         chennai   22:50              mumbai
# 1594         indigo     22:25         chennai   00:20              mumbai
# 1595  airasia india     06:55         chennai   21:00              mumbai
# 1596         indigo     08:30         chennai   10:20              mumbai
# 1597         indigo     20:00         chennai   21:55              mumbai
#
#                Total_Stops                         Duration    Price
# 0     1 stop via hyderabad  08 h 55 m\n1 stop via hyderabad  ₹ 5,988
# 1                 non stop              02 h 50 m\nnon stop  ₹ 7,107
# 2                 non stop              02 h 55 m\nnon stop  ₹ 7,184
# 3     1 stop via hyderabad  05 h 25 m\n1 stop via hyderabad  ₹ 7,487
# 4                 non stop              02 h 50 m\nnon stop  ₹ 7,499
# ...                    ...                              ...      ...
# 1593              non-stop                              2hr     2910
# 1594              non-stop                        1hr 55min     2914
# 1595                1 stop                        14hr 5min     3149
# 1596              non-stop                        1hr 50min     3400
# 1597              non-stop                        1hr 55min     3400
#
# [1309 rows x 8 columns]

# %%
# lets check the count for stops
data['Total_Stops'].value_counts()
# Out:
# 1 stop                  636
# non stop                484
# 2 stop                  133
# non-stop                 35
# 1 stop via hyderabad      6
# 2 stop(s)                 6
# 1 stop via bhopal         2
# 1 stop via nagpur         2
# 1 stop via mumbai         1
# 1 stop via ahmedabad      1
# 1 stop via lucknow        1
# 1 stop via goa            1
# 1 stop via shirdi         1
# Name: Total_Stops, dtype: int64

# %%
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via hyderabad','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via bhopal','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via nagpur','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via mumbai','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via ahmedabad','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via lucknow','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via goa','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('1 stop via shirdi','1 stop')
data['Total_Stops']=data['Total_Stops'].str.replace('non-stop','non stop')

# %%
data['Total_Stops']=data['Total_Stops'].replace("2 stop(s)","2 stop")

# %%
# lets check the count for stops again 
data['Total_Stops'].value_counts()
# Out:
# 1 stop      651
# non stop    519
# 2 stop      139
# Name: Total_Stops, dtype: int64

# %%
# Replaceing ',' and '₹' by using pandas string method
data['Price']=data['Price'].str.replace(',','')
data['Price']=data['Price'].str.replace('₹','')

# %%
#Recheck the column values
data['Price']=data['Price'].astype('float')

# %%
# Departure time is when a plane leaves the gate. 
# Similar to Date_of_Journey we can extract values from Dep_Time
Dep_Time_hours=[] # empty list
Dep_Time_minutes=[] # empty list
for i in data['Departure']:
    hour, minute = i.split(':')
    Dep_Time_hours.append(int(hour)) # Extracting Hours
    Dep_Time_minutes.append(int(minute)) # Extracting minutes

# adding this list as column to our dataset & drop the Dep_Time columns
data['Dep_Time_hours']=Dep_Time_hours
data['Dep_Time_minutes']=Dep_Time_minutes
data=data.drop(columns=["Departure"],axis=1)
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival Arrival_Destination Total_Stops  \
# 0      indigo       new delhi   00:05           bengaluru      1 stop
# 1    go first       new delhi   08:35           bengaluru    non stop
# 2     vistara       new delhi   08:30           bengaluru    non stop
#
#                           Duration   Price  Dep_Time_hours  Dep_Time_minutes
# 0  08 h 55 m\n1 stop via hyderabad  5988.0              15                10
# 1              02 h 50 m\nnon stop  7107.0               5                45
# 2              02 h 55 m\nnon stop  7184.0               5                35

# %%
# Arrival time is when the plane pulls up to the gate.
# Similar to Date_of_Journey we can extract values from Arrival_Time

Arv_Time_hours=[] # empty list
Arv_Time_minutes=[] # empty list
for i in data['Arrival']:
    hour, minute = i.split(':')
    Arv_Time_hours.append(int(hour)) # Extracting Hours
    Arv_Time_minutes.append(minute) # Extracting minutes

# adding this list as column to our dataset & drop the Dep_Time columns
data['Arv_Time_hours']=Arv_Time_hours
data['Arv_Time_minutes']=Arv_Time_minutes
data=data.drop(columns=["Arrival"],axis=1)
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival_Destination Total_Stops  \
# 0      indigo       new delhi           bengaluru      1 stop
# 1    go first       new delhi           bengaluru    non stop
# 2     vistara       new delhi           bengaluru    non stop
#
#                           Duration   Price  Dep_Time_hours  Dep_Time_minutes  \
# 0  08 h 55 m\n1 stop via hyderabad  5988.0              15                10
# 1              02 h 50 m\nnon stop  7107.0               5                45
# 2              02 h 55 m\nnon stop  7184.0               5                35
#
#    Arv_Time_hours Arv_Time_minutes
# 0               0               05
# 1               8               35
# 2               8               30

# %%
# As we dropduplicates ann remove unneccesary data lets reset the index first 
data.reset_index(inplace=True)

# %%
data
# Out:
#       index    Flight_Name Departure_Place Arrival_Destination Total_Stops  \
# 0         0         indigo       new delhi           bengaluru      1 stop
# 1         1       go first       new delhi           bengaluru    non stop
# 2         2        vistara       new delhi           bengaluru    non stop
# 3         3         indigo       new delhi           bengaluru      1 stop
# 4         4         indigo       new delhi           bengaluru    non stop
# ...     ...            ...             ...                 ...         ...
# 1304   1593      akasa air         chennai              mumbai    non stop
# 1305   1594         indigo         chennai              mumbai    non stop
# 1306   1595  airasia india         chennai              mumbai      1 stop
# 1307   1596         indigo         chennai              mumbai    non stop
# 1308   1597         indigo         chennai              mumbai    non stop
#
#                              Duration   Price  Dep_Time_hours  \
# 0     08 h 55 m\n1 stop via hyderabad  5988.0              15
# 1                 02 h 50 m\nnon stop  7107.0               5
# 2                 02 h 55 m\nnon stop  7184.0               5
# 3     05 h 25 m\n1 stop via hyderabad  7487.0              19
# 4                 02 h 50 m\nnon stop  7499.0               5
# ...                               ...     ...             ...
# 1304                              2hr  2910.0              20
# 1305                        1hr 55min  2914.0              22
# 1306                        14hr 5min  3149.0               6
# 1307                        1hr 50min  3400.0               8
# 1308                        1hr 55min  3400.0              20
#
#       Dep_Time_minutes  Arv_Time_hours Arv_Time_minutes
# 0                   10               0               05
# 1                   45               8               35
# 2                   35               8               30
# 3                   45               1               10
# 4                   55               8               45
# ...                ...             ...              ...
# 1304                50              22               50
# 1305                25               0               20
# 1306                55              21               00
# 1307                30              10               20
# 1308                 0              21               55
#
# [1309 rows x 11 columns]

# %%
#Droppng the duoble index column
data.drop(columns='index', inplace=True)

# %%
# While doing the EDA we seen there are some unique values are prsent in the Arival time minute so lets check and deal with it first 
data['Arv_Time_minutes'].unique()
# Out:
# array(['05', '35', '30', '10', '45', '55', '20', '40', '25', '15', '00',
#        '50', '50\n+ 1 day', '15\n+ 1 day', '45\n+ 1 day', '05\n+ 1 day',
#        '10\n+ 1 day', '20\n+ 1 day', '25\n+ 1 day', '35\n+ 1 day',
#        '40\n+ 1 day', '00\n+ 1 day', '30\n+ 1 day', '55\n+ 1 day'],
#       dtype=object)

# %%
def next_day(x):
    if "\n" in x:
        return "Yes"
    else:
        return "No"

# %%
#if flight reaches the destination next day i.e after 12 am
data['Next_day_Arrival']=data['Arv_Time_minutes'].apply(next_day)

# %%
# flight start to reach the destination i.e after 12 am
data['Next_day_dept']=data['Duration'].apply(next_day)

# %%
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival_Destination Total_Stops  \
# 0      indigo       new delhi           bengaluru      1 stop
# 1    go first       new delhi           bengaluru    non stop
# 2     vistara       new delhi           bengaluru    non stop
#
#                           Duration   Price  Dep_Time_hours  Dep_Time_minutes  \
# 0  08 h 55 m\n1 stop via hyderabad  5988.0              15                10
# 1              02 h 50 m\nnon stop  7107.0               5                45
# 2              02 h 55 m\nnon stop  7184.0               5                35
#
#    Arv_Time_hours Arv_Time_minutes Next_day_Arrival Next_day_dept
# 0               0               05               No           Yes
# 1               8               35               No           Yes
# 2               8               30               No           Yes

# %%
data['Arv_Time_minutes']=data['Arv_Time_minutes'].str.replace('1 day',' ')

# %%
data['Arv_Time_minutes']=data['Arv_Time_minutes'].str.replace('\n+',' ')

# %%
data['Arv_Time_minutes']=data['Arv_Time_minutes'].str.replace('+',' ')

# %%
data['Arv_Time_minutes']=data['Arv_Time_minutes'].str.replace(' ','')

# %%
# Rechek for the unique values and that treated well
data['Arv_Time_minutes'].unique()
# Out:
# array(['05', '35', '30', '10', '45', '55', '20', '40', '25', '15', '00',
#        '50'], dtype=object)

# %%
data['Arv_Time_minutes']=data['Arv_Time_minutes'].astype('int')

# %%
data['Duration']=data['Duration'].str.replace('\n',' ')
data['Duration']=data['Duration'].str.replace('non stop','')
data['Duration']=data['Duration'].str.replace('1 stop via','')
data['Duration']=data['Duration'].str.replace('hyderabad','')
data['Duration']=data['Duration'].str.replace('nagpur','')
data['Duration']=data['Duration'].str.replace('lucknow','')
data['Duration']=data['Duration'].str.replace('nagpur','')
data['Duration']=data['Duration'].str.replace('goa','')
data['Duration']=data['Duration'].str.replace('bhopal','')
data['Duration']=data['Duration'].str.replace('mumbai','')
data['Duration']=data['Duration'].str.replace('ahmedabad','')
data['Duration']=data['Duration'].str.replace('shirdi','')

# %%
data['Duration'].unique()
# Out:
# array(['08 h 55 m  ', '02 h 50 m ', '02 h 55 m ', '05 h 25 m  ',
#        '02 h 35 m ', '02 h 45 m ', '03 h ', '06 h 10 m  ', '03 h 05 m ',
#        '03 h 25 m ', '04 h 50 m  ', '06 h 30 m  ', '02 h 40 m ',
#        '03 h 20 m ', '06 h 15 m  ', '04 h 55 m  ', '04 h 25 m  ',
#        '08 h  ', '02 h 30 m ', '05 h  ', '06 h 35 m  ', '09h 40m',
#        '16h 40m', '18h 40m', '19h 35m', '17h 15m', '20h 30m', '09h 4m',
#        '11h 5m', '13h 4m', '10h 25m', '11h 20m', '12h 40m', '14h 35m',
#        '19h 05m', '15h 25m', '16h 45m', '17h 50m', '19h 10m', '20h 35m',
#        '10h 50m', '24h 15m', '12h 10m', '06h 05m', '15h 30m', '10h 05m',
#        '12h 45m', '14h 55m', '16h 00m', '17h 20m', '08h 20m', '05h 45m',
#        '12h 15m', '30h 35m', '11h 15m', '10h 2m', '23h 4m', '27h 00m',
#        '28h 50m', '12h 1m', '25h 25m', '05h 55m', '07h 4m', '08h 5m',
#        '10h 4m', '11h 2m', '13h 1m', '26h 20m', '13h 50m', '13h 05m',
#        '16h 25m', '24h 00m', '17h 00m', '17h 55m', '18h 05m', '17h 5m',
#        '06h 00m', '26h 25m', '13h 30m', '17h 40m', '18h 20m', '19h 20m',
#        '20h 25m', '21h 20m', '24h 20m', '24h 40m', '25h 40m', '26h 45m',
#        '27h 40m', '07h 50m', '22h 0m', '22h 5m', '23h 0m', '23h 5m',
#        '24h 1m', '24h 5m', '25h 0m', '25h 1m', '14h 20m', '14h 25m',
#        '19h 00m', '21h 55m', '25h 10m', '25h 15m', '28h 40m', '32h 10m',
#        '14h 30m', '26h 35m', '32h 55m', '20h 10m', '34h 50m', '13h 55m',
#        '15h 00m', '16h 10m', '16h 55m', '11h 45m', '24h 0m', '31h 15m',
#        '23h 15m', '26h 05m', '08h 30m', '09h 15m', '11h 30m', '05h 30m',
#        '31h 20m', '24h 55m', '25h 45m', '26h 15m', '26h 00m', '21h 00m',
#        '21h 25m', '10h 30m', '02h 25m', '07h 55m', '08h 40m', '02h 15m',
#        '02h 00m', '02h 10m', '02h 20m', '02h 05m', '02h 30m', '06h 1m',
#        '06h 10m', '05h 00m', '11h 00m', '12h 35m', '05h 15m', '05h 10m',
#        '05h 20m', '06h 50m', '12h 50m', '14h 50m', '15h 15m', '16h 15m',
#        '26h 10m', '06h 40m', '05h 40m', '25h 55m', '27h 10m', '06h 35m',
#        '05h 05m', '19h 45m', '14h 45m', '15h 50m', '06h 25m', '38h 50m',
#        '07h 05m', '06h 55m', '09h 45m', '10h 55m', '12h 30m', '04h 55m',
#        '05h 35m', '10h 10m', '12h 00m', '25h 05m', '15h 05m', '14h 15m',
#        '15h 10m', '16h 35m', '24h 30m', '07h 10m', '26h 30m', '08h 15m',
#        '08h 05m', '11h 50m', '12h 55m', '27h 15m', '22h 55m', '09h 10m',
#        '20h 00m', '06h 30m', '06h 15m', '12h 05m', '16h 50m', '19h 30m',
#        '08h 00m', '10h 00m', '12h 20m', '33h 05m', '06h 45m', '07h 45m',
#        '09h 00m', '22h 35m', '37h 10m', '39h 15m', '40h 35m', '04h 35m',
#        '05h 25m', '16h 30m', '21h 30m', '15h 40m', '11h 10m', '13h 25m',
#        '08h 25m', '09h 3m', '05h 50m', '22h 10m', '36h 40m', '19h 25m',
#        '04h 45m', '04h 40m', '27h 20m', '33h 20m', '30h 55m', '38h 00m',
#        '11h 05m', '29h 25m', '34h 35m', '01h 25m', '01h 30m', '01h 15m',
#        '01h 10m', '01h 20m', '01h 40m', '18h 55m', '11h 40m', '07h 40m',
#        '14h 40m', '22h 05m', '24h 35m', '08h 35m', '22h 45m', '08h 55m',
#        '09h 25m', '15h 20m', '15h 55m', '20h 15m', '23h 25m', '24h 25m',
#        '25h 35m', '26h 50m', '27h 45m', '18h 35m', '21h 35m', '27h 35m',
#        '28h 35m', '18h 30m', '38h 45m', '16h 2m', '18h 4m', '20h 2m',
#        '27h 30m', '28h 05m', '35h 35m', '17h 25m', '13h 35m', '25h 20m',
#        '21h 5m', '09h 05m', '06h 20m', '07h 20m', '31h 05m', '30h 05m',
#        '07h 15m', '18h 00m', '10h 35m', '39h 00m', '30h 15m', '38h 35m',
#        '01h 55m', '22h 1m', '27h 50m', '22h 25m', '24h 10m', '10h 20m',
#        '11h 35m', '27h 25m', '23h 20m', '21h 10m', '23h 10m', '20h 20m',
#        '15h 3m', '13h 00m', '14h 5m', '16h 05m', '21h 0m', '26h 3m',
#        '23h 3m', '28h 25m', '18h 1m', '18h 25m', '17h 10m', '6h 45m',
#        '6h 10m', '8h 55m', '2h 10m', '2h 15m', '2h 20m', '2h 25m',
#        '3h 45m', '6h 40m', '4h 40m', '2h 40m', '2h 45m', '2h 55m',
#        '3h 00m', '3h 20m', '3h 25m', '2h 50m', '2h 35m', '3h 05m',
#        '2h 30m', '4h 00m', '6h 05m', '8h 05m', '9h 25m', '10h 45m',
#        '7h 35m', '5h 35m', '8h 50m', '7h 30m', '9h 05m', '14h 05m',
#        '25h 50m', '5h 55m', '6h 20m', '6h 30m', '6h 35m', '6h 50m',
#        '1h 30m', '1h 40m', '1h 35m', '11h 55m', '4h 25m', '2h 00m',
#        '2h 05m', '1h 50m', '1h 45m', '8h 15m', '9h 30m', '9h 40m',
#        '11h 25m', '13h 40m', '15h 45m', '21h 40m', '7h 50m', '22h 30m',
#        '23h 45m', '8h 45m', '5h 50m', '23h 00m', '1h 55m', '5h 10m',
#        '6h 00m', '1h 20m', '1h 10m', '1h 15m', '1h 00m', '14h 10m',
#        '8h 25m', '9h 35m', '1h 05m', '1h 25m', '7h 40m', '7h 45m',
#        '5h 15m', '7h 15m', '4h 10m', '5h 00m', '7h 05m', '9h 00m',
#        '9h 45m', '4h 20m', '5h 45m', '8h 35m', '8h 40m', '9h 10m',
#        '6h 15m', '7h 20m', '6h 55m', '8h 30m', '23h 50m', '7h 25m',
#        '8h 00m', '7h 10m', '3h 10m', '7h 00m', '4h 55m', '13h 20m',
#        '15h 35m', '5h 40m', '7h 55m', '13h 10m', '2hr', '2hr 5min',
#        '2hr 10min', '1hr 55min', '11hr 45min', '6hr 5min', '8hr 5min',
#        '12hr 5min', '14hr 5min', '1hr 50min', '5hr 25min', '6hr 30min',
#        '4hr 15min', '11hr 35min', '4hr 45min', '4hr 10min', '7hr',
#        '5hr 35min'], dtype=object)

# %%
# Time taken by plane to reach destination is called Duration
# It is the differnce betwwen Departure Time and Arrival time

from datetime import datetime, timedelta
s=pd.to_timedelta(data['Duration'])

# Extracting Hours
data['Duration_hours']=s.dt.components['hours']


# Extracting Minutes
data['Duration_minutes']=s.dt.components['minutes']

# Now we can drop Arrival_Time as it is of no use
data.drop(["Duration"], axis = 1, inplace = True)
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival_Destination Total_Stops   Price  \
# 0      indigo       new delhi           bengaluru      1 stop  5988.0
# 1    go first       new delhi           bengaluru    non stop  7107.0
# 2     vistara       new delhi           bengaluru    non stop  7184.0
#
#    Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  Arv_Time_minutes  \
# 0              15                10               0                 5
# 1               5                45               8                35
# 2               5                35               8                30
#
#   Next_day_Arrival Next_day_dept  Duration_hours  Duration_minutes
# 0               No           Yes               8                55
# 1               No           Yes               2                50
# 2               No           Yes               2                55

# %% [markdown]
# As we have to analyse What is the best time to buy so that the consumer can save the most by taking the least risk?

# %%
# Lets create one new column with details of best time 
best_time=[]
for x in data['Dep_Time_hours']:
    if (x > 4) and (x <= 8):
        best_time.append('Early Morning') 
    elif (x > 8) and (x <= 12 ):
        best_time.append('Morning') 
    elif (x > 12) and (x <= 16):
        best_time.append('Noon')
    elif (x > 16) and (x <= 20) :
        best_time.append('Evening')
    elif (x > 20) and (x <= 24):
        best_time.append('Night')
    elif (x <= 4):
        best_time.append('Late Night')
data['best_time_dept']=best_time

# %%
# Recheck
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival_Destination Total_Stops   Price  \
# 0      indigo       new delhi           bengaluru      1 stop  5988.0
# 1    go first       new delhi           bengaluru    non stop  7107.0
# 2     vistara       new delhi           bengaluru    non stop  7184.0
#
#    Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  Arv_Time_minutes  \
# 0              15                10               0                 5
# 1               5                45               8                35
# 2               5                35               8                30
#
#   Next_day_Arrival Next_day_dept  Duration_hours  Duration_minutes  \
# 0               No           Yes               8                55
# 1               No           Yes               2                50
# 2               No           Yes               2                55
#
#   best_time_dept
# 0           Noon
# 1  Early Morning
# 2  Early Morning

# %%
# Lets create one new column with details of best time 
best_time1=[]
for x in data['Arv_Time_hours']:
    if (x > 4) and (x <= 8):
        best_time1.append('Early Morning') 
    elif (x > 8) and (x <= 12 ):
        best_time1.append('Morning') 
    elif (x > 12) and (x <= 16):
        best_time1.append('Noon')
    elif (x > 16) and (x <= 20) :
        best_time1.append('Evening')
    elif (x > 20) and (x <= 24):
        best_time1.append('Night')
    elif (x <= 4):
        best_time1.append('Late Night')
data['best_time_arrive']=best_time1
# Recheck
data.head(3)
# Out:
#   Flight_Name Departure_Place Arrival_Destination Total_Stops   Price  \
# 0      indigo       new delhi           bengaluru      1 stop  5988.0
# 1    go first       new delhi           bengaluru    non stop  7107.0
# 2     vistara       new delhi           bengaluru    non stop  7184.0
#
#    Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  Arv_Time_minutes  \
# 0              15                10               0                 5
# 1               5                45               8                35
# 2               5                35               8                30
#
#   Next_day_Arrival Next_day_dept  Duration_hours  Duration_minutes  \
# 0               No           Yes               8                55
# 1               No           Yes               2                50
# 2               No           Yes               2                55
#
#   best_time_dept best_time_arrive
# 0           Noon       Late Night
# 1  Early Morning    Early Morning
# 2  Early Morning    Early Morning

# %% [markdown]
# As we have Null values present in our dataset lets deal with it by using Mode techniques.

# %%
data.isnull().sum()
# Out:
# Flight_Name            94
# Departure_Place        91
# Arrival_Destination    44
# Total_Stops             0
# Price                   0
# Dep_Time_hours          0
# Dep_Time_minutes        0
# Arv_Time_hours          0
# Arv_Time_minutes        0
# Next_day_Arrival        0
# Next_day_dept           0
# Duration_hours          0
# Duration_minutes        0
# best_time_dept          0
# best_time_arrive        0
# dtype: int64

# %%
# Lets deal with Flight_Name null values by using numpy and pandas method
data['Flight_Name']=data['Flight_Name'].replace(" ",np.NaN)
data['Flight_Name']=data['Flight_Name'].fillna((data['Flight_Name'].mode()[0]))

# %%
# Lets deal with Departure_Place null values by using numpy and pandas method
data['Departure_Place']=data['Departure_Place'].replace(" ",np.NaN)
data['Departure_Place']=data['Departure_Place'].fillna((data['Arrival_Destination'].mode()[0]))

# %%
# Lets deal with Arrival_Destination null values by using numpy and pandas method
data['Arrival_Destination']=data['Arrival_Destination'].replace(" ",np.NaN)
data['Arrival_Destination']=data['Arrival_Destination'].fillna((data['Arrival_Destination'].mode()[0]))

# %%
# Lets recheck for the Null values is treated well or not.
data.isnull().sum()
# Out:
# Flight_Name            0
# Departure_Place        0
# Arrival_Destination    0
# Total_Stops            0
# Price                  0
# Dep_Time_hours         0
# Dep_Time_minutes       0
# Arv_Time_hours         0
# Arv_Time_minutes       0
# Next_day_Arrival       0
# Next_day_dept          0
# Duration_hours         0
# Duration_minutes       0
# best_time_dept         0
# best_time_arrive       0
# dtype: int64

# %% [markdown]
# Now our data looks great now lets move further .

# %%
#This is Our final Dataframe after data pre-Processing so lets save it first for our safeside.
data.to_csv('Flight_price_after_DPP.csv')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Plots

# %%
#plot each class frequency
plt.figure(figsize =(15,6))
sns.countplot(y='Flight_Name',data=data)
plt.show()
print(data['Flight_Name'].value_counts())
# Out:
# vistara              354
# indigo               258
# air india            174
# air asia             138
# go first             111
# indigo air            75
# spicejet              65
# multiple airlines     34
# emirates              13
# airasia india         10
# malaysia air           8
# spice jet              8
# alliance air           7
# qatar airways          7
# airasia                5
# akasa air              5
# go air                 4
# thai intl              4
# jatayu airlines        3
# british airways        3
# all nippon             2
# malindo air            2
# asiana airlines        2
# srilankan              2
# singapore airl         2
# hahn air               2
# flexflight aps         2
# etihad airways         1
# turkish airlines       1
# biman bangladesh       1
# swiss intl             1
# lufthansa              1
# myanmar airways        1
# vietnam air            1
# flybig                 1
# gulf air               1
# Name: Flight_Name, dtype: int64

# %% [markdown]
# From graph we can see that there are maximum peoples are travelled form vistara(260) and indigo(258) airlines.

# %%
#plot each class frequency
plt.figure(figsize =(8,4))
sns.countplot(x='Departure_Place',data=data)
plt.show()
print(data['Departure_Place'].value_counts())
# Out:
# new delhi    358
# hyderabad    334
# mumbai       315
# singapore    135
# kolkata      110
# chennai       57
# Name: Departure_Place, dtype: int64

# %% [markdown]
# People are used Maximum time departure place as new delhi and hydrabad.

# %%
#plot each class frequency
plt.figure(figsize =(8,4))
sns.countplot(x='Total_Stops',data=data)
plt.show()
print(data['Total_Stops'].value_counts())
# Out:
# 1 stop      651
# non stop    519
# 2 stop      139
# Name: Total_Stops, dtype: int64

# %% [markdown]
# There are maximum no of flight who have 1 stop.

# %%
#plot each class frequency
plt.figure(figsize =(8,4))
sns.catplot(y='Price',data=data)
plt.show()
print(data['Price'].value_counts())
# Out:
# 15078.0    38
# 4687.0     32
# 6507.0     26
# 58802.0    18
# 4765.0     17
#            ..
# 23167.0     1
# 23113.0     1
# 23598.0     1
# 22223.0     1
# 3149.0      1
# Name: Price, Length: 507, dtype: int64

# %% [markdown]
# Outliers are present in the target variable

# %% [markdown]
# # Bivariate Plot

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='Arrival_Destination', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# From graph we can see that the new delhi flight has maximum rate or price.

# %%
#Bivariant graph
plt.figure(figsize =(15,8))
sns.barplot(y ='Flight_Name', x ='Price', data = data)
plt.show()

# %% [markdown]
# From graph we can see the price for all nippon has very expensive flights and airasia, akasa air, indigo, gofirst airlines has cheap flights.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='Total_Stops', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# The price are high for the 1 stop flights

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='Arrival_Destination', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# For the new delhi arival place has maximum price.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='best_time_dept', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# From graph we cam see that the prices are high for the night flights and cheap for the early morning flights. So the best time to buy the tickets for the early morning flights.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='best_time_arrive', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# From graph we can see that the best time for the arrival is Noon as flight charges for the noon flights are very cheap.

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='Next_day_dept', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# From graph we can see that the prices are very low for the long route .

# %%
#Bivariant graph
plt.figure(figsize =(10, 6))
sns.catplot(x ='Next_day_Arrival', y ='Price', data = data, kind = "boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# From grapf we can see that the prices are very high for the next dat arrival flight means for the long journy.

# %% [markdown]
# # Data Processesing

# %%
# lets seaprate the catogorical data & numirical data
numerics=['int8','int16','int32','int64','float16','float32','float64']
cat_col=[] #empty list
features=data.columns.values.tolist()
for i in features:
    if data[i].dtype in numerics:
        continue
    cat_col.append(i)
cat_col
# Out:
# ['Flight_Name',
#  'Departure_Place',
#  'Arrival_Destination',
#  'Total_Stops',
#  'Next_day_Arrival',
#  'Next_day_dept',
#  'best_time_dept',
#  'best_time_arrive']

# %% [markdown]
# As we have objective type data so lets deal with it by using encoding techniques and convert them into int.

# %%
# Lets frist covert categorical data(type & column) into int 
label = LabelEncoder()
for i in cat_col:
    df=label.fit_transform(data[i])
    pd.Series(df)
    data[i]=df

# %%
# Recheck the data after encoding into numerical values
data.head()
# Out:
#    Flight_Name  Departure_Place  Arrival_Destination  Total_Stops   Price  \
# 0           18                4                    3            0  5988.0
# 1           15                4                    3            2  7107.0
# 2           35                4                    3            2  7184.0
# 3           18                4                    3            0  7487.0
# 4           18                4                    3            2  7499.0
#
#    Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  Arv_Time_minutes  \
# 0              15                10               0                 5
# 1               5                45               8                35
# 2               5                35               8                30
# 3              19                45               1                10
# 4               5                55               8                45
#
#    Next_day_Arrival  Next_day_dept  Duration_hours  Duration_minutes  \
# 0                 0              1               8                55
# 1                 0              1               2                50
# 2                 0              1               2                55
# 3                 0              1               5                25
# 4                 0              1               2                50
#
#    best_time_dept  best_time_arrive
# 0               5                 2
# 1               0                 0
# 2               0                 0
# 3               1                 2
# 4               0                 0

# %%
print(data.shape)
# Out:
# (1309, 15)

# %%
data.columns
# Out:
# Index(['Flight_Name', 'Departure_Place', 'Arrival_Destination', 'Total_Stops',
#        'Price', 'Dep_Time_hours', 'Dep_Time_minutes', 'Arv_Time_hours',
#        'Arv_Time_minutes', 'Next_day_Arrival', 'Next_day_dept',
#        'Duration_hours', 'Duration_minutes', 'best_time_dept',
#        'best_time_arrive'],
#       dtype='object')

# %% [markdown]
# # Multivarinate Plot

# %%
#Let's see the how data is distributed or Graphical analysis of all features
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=70:
        ax=plt.subplot(10,7,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From graph we can see that the data has skweness which we need to fix it.

# %%
# See again Statistical Summary
# Lets understand data at high level check the stastics of dataset
data.describe(include='all')
# Out:
#        Flight_Name  Departure_Place  Arrival_Destination  Total_Stops  \
# count  1309.000000      1309.000000          1309.000000  1309.000000
# mean     18.730328         2.754775             9.341482     0.899160
# std      12.899215         1.457419             4.614526     0.940382
# min       0.000000         0.000000             0.000000     0.000000
# 25%       4.000000         1.000000             6.000000     0.000000
# 50%      18.000000         3.000000            11.000000     1.000000
# 75%      35.000000         4.000000            13.000000     2.000000
# max      35.000000         5.000000            20.000000     2.000000
#
#                Price  Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  \
# count    1309.000000     1309.000000       1309.000000     1309.000000
# mean    15626.639801       13.477464         26.390374       13.878533
# std     32566.067558        5.932636         17.707259        6.643712
# min         0.000000        0.000000          0.000000        0.000000
# 25%      5083.000000        8.000000         10.000000        9.000000
# 50%      7732.000000       14.000000         25.000000       14.000000
# 75%     15188.000000       19.000000         40.000000       20.000000
# max    531226.000000       23.000000         55.000000       23.000000
#
#        Arv_Time_minutes  Next_day_Arrival  Next_day_dept  Duration_hours  \
# count       1309.000000       1309.000000    1309.000000     1309.000000
# mean          28.938121          0.114591       0.055004        6.723453
# std           17.353008          0.318650       0.228075        6.202242
# min            0.000000          0.000000       0.000000        0.000000
# 25%           15.000000          0.000000       0.000000        2.000000
# 50%           30.000000          0.000000       0.000000        5.000000
# 75%           45.000000          0.000000       0.000000       11.000000
# max           55.000000          1.000000       1.000000       23.000000
#
#        Duration_minutes  best_time_dept  best_time_arrive
# count       1309.000000     1309.000000       1309.000000
# mean          26.503438        2.209320          2.595111
# std           17.429878        1.830477          1.733685
# min            0.000000        0.000000          0.000000
# 25%           10.000000        1.000000          1.000000
# 50%           25.000000        2.000000          3.000000
# 75%           40.000000        4.000000          4.000000
# max           55.000000        5.000000          5.000000

# %% [markdown]
# Observation:-1) Null values are treated well. 2)Diffrance between mean & std. 3)outliers and skwed data is present.

# %% [markdown]
# All null values are treated well now lets move further for the skewness & colinarity

# %% [markdown]
# From graph we can see that the almost every columns have skewness, now lets check with skew values also.

# %%
# Check skewness by skew value
data.skew().sort_values(ascending=False)
# Out:
# Price                  9.206161
# Next_day_dept          3.908165
# Next_day_Arrival       2.422713
# Duration_hours         0.967808
# best_time_dept         0.220955
# Total_Stops            0.201889
# Duration_minutes       0.080891
# Dep_Time_minutes       0.079344
# Arv_Time_minutes      -0.044757
# best_time_arrive      -0.109289
# Flight_Name           -0.130822
# Dep_Time_hours        -0.150868
# Departure_Place       -0.202769
# Arrival_Destination   -0.296646
# Arv_Time_hours        -0.423590
# dtype: float64

# %% [markdown]
# As we seen in almost all columns we have skewness so lets deal with it.

# %% [markdown]
# Lets use advance tech. to remove this skewness using Power transformation

# %%
# Separate the skewed columns
df1=['Flight_Name', 'Departure_Place', 'Arrival_Destination', 'Total_Stops',
       'Price', 'Dep_Time_hours','Arv_Time_hours',
       'Next_day_Arrival', 'Next_day_dept',
       'Duration_hours', 'best_time_dept',
       'best_time_arrive']

# %%
data.astype('int')
# Out:
#       Flight_Name  Departure_Place  Arrival_Destination  Total_Stops  Price  \
# 0              18                4                    3            0   5988
# 1              15                4                    3            2   7107
# 2              35                4                    3            2   7184
# 3              18                4                    3            0   7487
# 4              18                4                    3            2   7499
# ...           ...              ...                  ...          ...    ...
# 1304            4                0                   12            2   2910
# 1305           18                0                   12            2   2914
# 1306            3                0                   12            0   3149
# 1307           18                0                   12            2   3400
# 1308           18                0                   12            2   3400
#
#       Dep_Time_hours  Dep_Time_minutes  Arv_Time_hours  Arv_Time_minutes  \
# 0                 15                10               0                 5
# 1                  5                45               8                35
# 2                  5                35               8                30
# 3                 19                45               1                10
# 4                  5                55               8                45
# ...              ...               ...             ...               ...
# 1304              20                50              22                50
# 1305              22                25               0                20
# 1306               6                55              21                 0
# 1307               8                30              10                20
# 1308              20                 0              21                55
#
#       Next_day_Arrival  Next_day_dept  Duration_hours  Duration_minutes  \
# 0                    0              1               8                55
# 1                    0              1               2                50
# 2                    0              1               2                55
# 3                    0              1               5                25
# 4                    0              1               2                50
# ...                ...            ...             ...               ...
# 1304                 0              0               2                 0
# 1305                 0              0               1                55
# 1306                 0              0              14                 5
# 1307                 0              0               1                50
# 1308                 0              0               1                55
#
#       best_time_dept  best_time_arrive
# 0                  5                 2
# 1                  0                 0
# 2                  0                 0
# 3                  1                 2
# 4                  0                 0
# ...              ...               ...
# 1304               1                 4
# 1305               4                 2
# 1306               0                 4
# 1307               0                 3
# 1308               1                 4
#
# [1309 rows x 15 columns]

# %%
# Using power transformation to remove skewed data
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
data[df1]=pt.fit_transform(data[df1].values)
data[df1] # rechek data
# Out:
#       Flight_Name  Departure_Place  Arrival_Destination  Total_Stops  \
# 0        0.090720         0.854729            -1.372627    -0.984382
# 1       -0.124240         0.854729            -1.372627     1.122251
# 2        1.145304         0.854729            -1.372627     1.122251
# 3        0.090720         0.854729            -1.372627    -0.984382
# 4        0.090720         0.854729            -1.372627     1.122251
# ...           ...              ...                  ...          ...
# 1304    -1.079969        -1.889348             0.573466     1.122251
# 1305     0.090720        -1.889348             0.573466     1.122251
# 1306    -1.192787        -1.889348             0.573466    -0.984382
# 1307     0.090720        -1.889348             0.573466     1.122251
# 1308     0.090720        -1.889348             0.573466     1.122251
#
#          Price  Dep_Time_hours  Arv_Time_hours  Next_day_Arrival  \
# 0    -0.453743        0.270044       -2.012438         -0.359753
# 1    -0.292326       -1.441945       -0.905655         -0.359753
# 2    -0.282041       -1.441945       -0.905655         -0.359753
# 3    -0.242462        0.929187       -1.886230         -0.359753
# 4    -0.240923       -1.441945       -0.905655         -0.359753
# ...        ...             ...             ...               ...
# 1304 -1.091850        1.092411        1.246008         -0.359753
# 1305 -1.090697        1.417208       -2.012438         -0.359753
# 1306 -1.025216       -1.264624        1.087459         -0.359753
# 1307 -0.959749       -0.915205       -0.609403         -0.359753
# 1308 -0.959749        1.092411        1.087459         -0.359753
#
#       Next_day_dept  Duration_hours  best_time_dept  best_time_arrive
# 0          4.144943        0.606446        1.336564         -0.281317
# 1          4.144943       -0.712698       -1.375264         -1.573428
# 2          4.144943       -0.712698       -1.375264         -1.573428
# 3          4.144943        0.132818       -0.510047         -0.281317
# 4          4.144943       -0.712698       -1.375264         -1.573428
# ...             ...             ...             ...               ...
# 1304      -0.241258       -0.712698       -0.510047          0.817123
# 1305      -0.241258       -1.229105        0.982205         -0.281317
# 1306      -0.241258        1.182027       -1.375264          0.817123
# 1307      -0.241258       -1.229105       -1.375264          0.283228
# 1308      -0.241258       -1.229105       -0.510047          0.817123
#
# [1309 rows x 12 columns]

# %%
# distribusion after transformation
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=70:
        ax=plt.subplot(10,7,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Lets Check Correlation

# %%
data.corr()
# Out:
#                      Flight_Name  Departure_Place  Arrival_Destination  \
# Flight_Name             1.000000         0.072899             0.070175
# Departure_Place         0.072899         1.000000            -0.116255
# Arrival_Destination     0.070175        -0.116255             1.000000
# Total_Stops            -0.068739         0.029045            -0.214710
# Price                   0.257987         0.357135             0.189901
# Dep_Time_hours         -0.006579         0.058707            -0.052079
# Dep_Time_minutes        0.059192        -0.005725            -0.044268
# Arv_Time_hours          0.169084        -0.006297             0.017456
# Arv_Time_minutes        0.096505         0.095341             0.013461
# Next_day_Arrival       -0.100184        -0.048197            -0.128225
# Next_day_dept           0.011704         0.206210            -0.331157
# Duration_hours          0.102330         0.024753             0.153817
# Duration_minutes        0.028003         0.058644            -0.149443
# best_time_dept         -0.114059         0.093114             0.030029
# best_time_arrive        0.148241        -0.003124             0.033577
#
#                      Total_Stops     Price  Dep_Time_hours  Dep_Time_minutes  \
# Flight_Name            -0.068739  0.257987       -0.006579          0.059192
# Departure_Place         0.029045  0.357135        0.058707         -0.005725
# Arrival_Destination    -0.214710  0.189901       -0.052079         -0.044268
# Total_Stops             1.000000 -0.297372       -0.029405         -0.007314
# Price                  -0.297372  1.000000        0.032052         -0.049837
# Dep_Time_hours         -0.029405  0.032052        1.000000          0.023724
# Dep_Time_minutes       -0.007314 -0.049837        0.023724          1.000000
# Arv_Time_hours          0.010389 -0.002845        0.144882          0.018211
# Arv_Time_minutes       -0.009168  0.058589        0.042340         -0.018642
# Next_day_Arrival       -0.239612 -0.205937        0.351824          0.078106
# Next_day_dept           0.164868 -0.007486       -0.048036          0.001873
# Duration_hours         -0.686875  0.279671        0.050209          0.027050
# Duration_minutes       -0.019329 -0.071042       -0.018119         -0.014792
# best_time_dept         -0.054072  0.044576        0.462222          0.099779
# best_time_arrive       -0.018557  0.072913        0.035501         -0.051506
#
#                      Arv_Time_hours  Arv_Time_minutes  Next_day_Arrival  \
# Flight_Name                0.169084          0.096505         -0.100184
# Departure_Place           -0.006297          0.095341         -0.048197
# Arrival_Destination        0.017456          0.013461         -0.128225
# Total_Stops                0.010389         -0.009168         -0.239612
# Price                     -0.002845          0.058589         -0.205937
# Dep_Time_hours             0.144882          0.042340          0.351824
# Dep_Time_minutes           0.018211         -0.018642          0.078106
# Arv_Time_hours             1.000000          0.036852         -0.338344
# Arv_Time_minutes           0.036852          1.000000         -0.085822
# Next_day_Arrival          -0.338344         -0.085822          1.000000
# Next_day_dept             -0.015798         -0.025797         -0.086793
# Duration_hours            -0.014057          0.037963          0.218797
# Duration_minutes          -0.025745          0.048784          0.017824
# best_time_dept             0.077572         -0.006719          0.154654
# best_time_arrive           0.367189          0.025023         -0.242862
#
#                      Next_day_dept  Duration_hours  Duration_minutes  \
# Flight_Name               0.011704        0.102330          0.028003
# Departure_Place           0.206210        0.024753          0.058644
# Arrival_Destination      -0.331157        0.153817         -0.149443
# Total_Stops               0.164868       -0.686875         -0.019329
# Price                    -0.007486        0.279671         -0.071042
# Dep_Time_hours           -0.048036        0.050209         -0.018119
# Dep_Time_minutes          0.001873        0.027050         -0.014792
# Arv_Time_hours           -0.015798       -0.014057         -0.025745
# Arv_Time_minutes         -0.025797        0.037963          0.048784
# Next_day_Arrival         -0.086793        0.218797          0.017824
# Next_day_dept             1.000000       -0.119420          0.194578
# Duration_hours           -0.119420        1.000000         -0.021419
# Duration_minutes          0.194578       -0.021419          1.000000
# best_time_dept           -0.049350       -0.004088          0.023480
# best_time_arrive          0.007541        0.085228         -0.046782
#
#                      best_time_dept  best_time_arrive
# Flight_Name               -0.114059          0.148241
# Departure_Place            0.093114         -0.003124
# Arrival_Destination        0.030029          0.033577
# Total_Stops               -0.054072         -0.018557
# Price                      0.044576          0.072913
# Dep_Time_hours             0.462222          0.035501
# Dep_Time_minutes           0.099779         -0.051506
# Arv_Time_hours             0.077572          0.367189
# Arv_Time_minutes          -0.006719          0.025023
# Next_day_Arrival           0.154654         -0.242862
# Next_day_dept             -0.049350          0.007541
# Duration_hours            -0.004088          0.085228
# Duration_minutes           0.023480         -0.046782
# best_time_dept             1.000000          0.054806
# best_time_arrive           0.054806          1.000000

# %% [markdown]
# From above .corr method we can sse the correlation between independant variable and dependant variable. There are some +ve and -ve correlation with target variable of independant variable. Lets visualise the same by plotting the heatmap.

# %%
#check multicolinearity
my_fig1=plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True,annot_kws={'size':10})
plt.show()

# %%
# Save graph 
plt.savefig('my_fig1.png')

# %%
# Check correlation with target variable
data.corr()['Price'].sort_values(ascending = True)
# Out:
# Total_Stops           -0.297372
# Next_day_Arrival      -0.205937
# Duration_minutes      -0.071042
# Dep_Time_minutes      -0.049837
# Next_day_dept         -0.007486
# Arv_Time_hours        -0.002845
# Dep_Time_hours         0.032052
# best_time_dept         0.044576
# Arv_Time_minutes       0.058589
# best_time_arrive       0.072913
# Arrival_Destination    0.189901
# Flight_Name            0.257987
# Duration_hours         0.279671
# Departure_Place        0.357135
# Price                  1.000000
# Name: Price, dtype: float64

# %% [markdown]
# We can see almost every column is corelated with target variable except Arv_Time_hours.Lets move further to check the outliers.

# %%
data.shape
# Out:
# (1309, 15)

# %%
#Let's see the outliers in the dataset by using box plot or Graphical analysis of all features
myFig=plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=70:
        ax=plt.subplot(10,7,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# No outliers are present in the dataset except target variable so lets divide dataset into target variable and local variables.

# %%
#As outliers present in target variable first remove it 
q1=data.quantile(0.25)
q3=data.quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# Flight_Name            -1.079969
# Departure_Place        -1.204453
# Arrival_Destination    -0.731643
# Total_Stops            -0.984382
# Price                  -0.604470
# Dep_Time_hours         -0.915205
# Dep_Time_minutes       10.000000
# Arv_Time_hours         -0.758150
# Arv_Time_minutes       15.000000
# Next_day_Arrival       -0.359753
# Next_day_dept          -0.241258
# Duration_hours         -0.712698
# Duration_minutes       10.000000
# best_time_dept         -0.510047
# best_time_arrive       -0.889917
# Name: 0.25, dtype: float64 Flight_Name             1.145304
# Departure_Place         0.854729
# Arrival_Destination     0.793053
# Total_Stops             1.122251
# Price                   0.472744
# Dep_Time_hours          0.929187
# Dep_Time_minutes       40.000000
# Arv_Time_hours          0.929513
# Arv_Time_minutes       45.000000
# Next_day_Arrival       -0.359753
# Next_day_dept          -0.241258
# Duration_hours          0.933441
# Duration_minutes       40.000000
# best_time_dept          0.982205
# best_time_arrive        0.817123
# Name: 0.75, dtype: float64 Flight_Name             2.225272
# Departure_Place         2.059182
# Arrival_Destination     1.524695
# Total_Stops             2.106633
# Price                   1.077214
# Dep_Time_hours          1.844392
# Dep_Time_minutes       30.000000
# Arv_Time_hours          1.687663
# Arv_Time_minutes       30.000000
# Next_day_Arrival        0.000000
# Next_day_dept           0.000000
# Duration_hours          1.646139
# Duration_minutes       30.000000
# best_time_dept          1.492252
# best_time_arrive        1.707040
# dtype: float64

# %%
Price_H=(q3.Price+(1.5*iqr.Price))
Price_H
# Out:
# 2.0885648273867403

# %%
Index=np.where(data['Price']>Price_H)
print(Index)
data=data.drop(data.index[Index])
data.shape
# Out:
# (array([160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172,
#        173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185,
#        186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198,
#        199, 200, 201, 202, 203, 204, 205, 206, 523], dtype=int64),)
# (1261, 15)

# %%
# Let's Seperate the data & visulize the relation between featurs & lable
x=data.drop(columns=['Price'])
y=data['Price']

# %%
# data stadardization
scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#check multicolinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["featurs"]=x.columns
print(vif)
# Out:
#          vif              featurs
# 0   1.103967          Flight_Name
# 1   1.109074      Departure_Place
# 2   1.237971  Arrival_Destination
# 3   2.136394          Total_Stops
# 4   1.621389       Dep_Time_hours
# 5   1.034527     Dep_Time_minutes
# 6   1.422873       Arv_Time_hours
# 7   1.046350     Arv_Time_minutes
# 8   1.725636     Next_day_Arrival
# 9   1.227847        Next_day_dept
# 10  2.082206       Duration_hours
# 11  1.067929     Duration_minutes
# 12  1.361204       best_time_dept
# 13  1.231117     best_time_arrive

# %% [markdown]
# As we can see that pvalues of above predictors is  not more than 10 so there is no multicolinarity.

# %%
# see how featurs r related to lable(Graphical Analysis)
plt.figure(figsize=(15,20))
plotnumber=1
for column in x:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.scatterplot(y,x[column])
    plotnumber+=1
plt.show()

# %%
print(x.shape)
print(y.shape)
# Out:
# (1261, 14)
# (1261,)

# %%
# Lets select the proper random state to build best model by using LinearRegression
from sklearn.ensemble import RandomForestRegressor

lr= RandomForestRegressor()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_train)
    pred=lr.predict(x_test)
    print(f"at random sate {i}, the training accuracy is:- {r2_score(y_train,y_pred)}")
    print(f"at random sate {i}, the testing accuracy is:- {r2_score(y_test,pred)}")
    print("\n")
# Out:
# at random sate 0, the training accuracy is:- 0.9743908255700804
# at random sate 0, the testing accuracy is:- 0.7225565603075434
#
#
# at random sate 1, the training accuracy is:- 0.9740693933859187
# at random sate 1, the testing accuracy is:- 0.8278911583459768
#
#
# at random sate 2, the training accuracy is:- 0.9654975225164426
# at random sate 2, the testing accuracy is:- 0.8481569483827403
#
#
# at random sate 3, the training accuracy is:- 0.9639279705914138
# at random sate 3, the testing accuracy is:- 0.8582797402834579
#
#
# at random sate 4, the training accuracy is:- 0.9684243301964655
# at random sate 4, the testing accuracy is:- 0.7099064307752265
#
#
# at random sate 5, the training accuracy is:- 0.9713059363790373
# at random sate 5, the testing accuracy is:- 0.8279448706835176
#
#
# at random sate 6, the training accuracy is:- 0.9641879040135545
# at random sate 6, the testing accuracy is:- 0.8447213720644393
#
#
# at random sate 7, the training accuracy is:- 0.9723242025027538
# at random sate 7, the testing accuracy is:- 0.8140402590766076
#
#
# at random sate 8, the training accuracy is:- 0.9693696413682678
# at random sate 8, the testing accuracy is:- 0.8217065518565692
#
#
# at random sate 9, the training accuracy is:- 0.9655769532889036
# at random sate 9, the testing accuracy is:- 0.7974876565218307
#
#
# at random sate 10, the training accuracy is:- 0.9664489441455216
# at random sate 10, the testing accuracy is:- 0.8786101470960389
#
#
# at random sate 11, the training accuracy is:- 0.9672861404616981
# at random sate 11, the testing accuracy is:- 0.8529872668383114
#
#
# at random sate 12, the training accuracy is:- 0.9713891038927152
# at random sate 12, the testing accuracy is:- 0.7354847789659651
#
#
# at random sate 13, the training accuracy is:- 0.9732042911291593
# at random sate 13, the testing accuracy is:- 0.706665294063154
#
#
# at random sate 14, the training accuracy is:- 0.9728805218880925
# at random sate 14, the testing accuracy is:- 0.7987191762270035
#
#
# at random sate 15, the training accuracy is:- 0.9712047663541885
# at random sate 15, the testing accuracy is:- 0.7609425808834663
#
#
# at random sate 16, the training accuracy is:- 0.9741449716762229
# at random sate 16, the testing accuracy is:- 0.7820962764678607
#
#
# at random sate 17, the training accuracy is:- 0.9676892373633037
# at random sate 17, the testing accuracy is:- 0.8317457917215161
#
#
# at random sate 18, the training accuracy is:- 0.9689989744224747
# at random sate 18, the testing accuracy is:- 0.780566653056651
#
#
# at random sate 19, the training accuracy is:- 0.9593159607637434
# at random sate 19, the testing accuracy is:- 0.8478052029768246
#
#
# at random sate 20, the training accuracy is:- 0.9762050858944052
# at random sate 20, the testing accuracy is:- 0.773539399954255
#
#
# at random sate 21, the training accuracy is:- 0.968973516009787
# at random sate 21, the testing accuracy is:- 0.8619848452877168
#
#
# at random sate 22, the training accuracy is:- 0.9757230047245468
# at random sate 22, the testing accuracy is:- 0.7467196416198355
#
#
# at random sate 23, the training accuracy is:- 0.9731791299102966
# at random sate 23, the testing accuracy is:- 0.799325381771587
#
#
# at random sate 24, the training accuracy is:- 0.9650217820415943
# at random sate 24, the testing accuracy is:- 0.8600002392818891
#
#
# at random sate 25, the training accuracy is:- 0.9660263143183727
# at random sate 25, the testing accuracy is:- 0.8232056705844033
#
#
# at random sate 26, the training accuracy is:- 0.9686121202132926
# at random sate 26, the testing accuracy is:- 0.765624486094726
#
#
# at random sate 27, the training accuracy is:- 0.9600313365932789
# at random sate 27, the testing accuracy is:- 0.8413133975236438
#
#
# at random sate 28, the training accuracy is:- 0.9618566623254374
# at random sate 28, the testing accuracy is:- 0.84278863390851
#
#
# at random sate 29, the training accuracy is:- 0.9691976026690682
# at random sate 29, the testing accuracy is:- 0.8041797206232586
#
#
# at random sate 30, the training accuracy is:- 0.9738941097095624
# at random sate 30, the testing accuracy is:- 0.7902462512306097
#
#
# at random sate 31, the training accuracy is:- 0.9725651400147892
# at random sate 31, the testing accuracy is:- 0.7802730920523608
#
#
# at random sate 32, the training accuracy is:- 0.9733443197823096
# at random sate 32, the testing accuracy is:- 0.7592288526593086
#
#
# at random sate 33, the training accuracy is:- 0.9653485627951388
# at random sate 33, the testing accuracy is:- 0.8152957267655835
#
#
# at random sate 34, the training accuracy is:- 0.9621931379071675
# at random sate 34, the testing accuracy is:- 0.8215919369249793
#
#
# at random sate 35, the training accuracy is:- 0.9655090769746443
# at random sate 35, the testing accuracy is:- 0.855647304996199
#
#
# at random sate 36, the training accuracy is:- 0.9664309611274858
# at random sate 36, the testing accuracy is:- 0.8301462901421145
#
#
# at random sate 37, the training accuracy is:- 0.9698420293952432
# at random sate 37, the testing accuracy is:- 0.6742082632436943
#
#
# at random sate 38, the training accuracy is:- 0.9733241108404048
# at random sate 38, the testing accuracy is:- 0.7748909082982973
#
#
# at random sate 39, the training accuracy is:- 0.9658412252230381
# at random sate 39, the testing accuracy is:- 0.8167201550235222
#
#
# at random sate 40, the training accuracy is:- 0.9710490334848703
# at random sate 40, the testing accuracy is:- 0.8536580327552625
#
#
# at random sate 41, the training accuracy is:- 0.9646747815489247
# at random sate 41, the testing accuracy is:- 0.8542063310586842
#
#
# at random sate 42, the training accuracy is:- 0.9700955097519774
# at random sate 42, the testing accuracy is:- 0.7279942939185831
#
#
# at random sate 43, the training accuracy is:- 0.9696138653999197
# at random sate 43, the testing accuracy is:- 0.7950493165362519
#
#
# at random sate 44, the training accuracy is:- 0.9735371229622871
# at random sate 44, the testing accuracy is:- 0.7763458140514454
#
#
# at random sate 45, the training accuracy is:- 0.965248057912283
# at random sate 45, the testing accuracy is:- 0.8510858466440183
#
#
# at random sate 46, the training accuracy is:- 0.9700000638467163
# at random sate 46, the testing accuracy is:- 0.8012725474452684
#
#
# at random sate 47, the training accuracy is:- 0.9743293870305073
# at random sate 47, the testing accuracy is:- 0.8002286753929952
#
#
# at random sate 48, the training accuracy is:- 0.9661069863015865
# at random sate 48, the testing accuracy is:- 0.7871849243132454
#
#
# at random sate 49, the training accuracy is:- 0.9698162499190184
# at random sate 49, the testing accuracy is:- 0.7991433800819048
#
#
# at random sate 50, the training accuracy is:- 0.9706277768459678
# at random sate 50, the testing accuracy is:- 0.7711863243934689
#
#
# at random sate 51, the training accuracy is:- 0.9623519608818015
# at random sate 51, the testing accuracy is:- 0.7887318486872421
#
#
# at random sate 52, the training accuracy is:- 0.9704985287757085
# at random sate 52, the testing accuracy is:- 0.7992752269707866
#
#
# at random sate 53, the training accuracy is:- 0.9697567057855947
# at random sate 53, the testing accuracy is:- 0.7805416056738255
#
#
# at random sate 54, the training accuracy is:- 0.9735024429803304
# at random sate 54, the testing accuracy is:- 0.8126800462290574
#
#
# at random sate 55, the training accuracy is:- 0.9654619237657635
# at random sate 55, the testing accuracy is:- 0.7502192004635616
#
#
# at random sate 56, the training accuracy is:- 0.9751579177756047
# at random sate 56, the testing accuracy is:- 0.8490193138155222
#
#
# at random sate 57, the training accuracy is:- 0.9675723771021415
# at random sate 57, the testing accuracy is:- 0.8353929450588583
#
#
# at random sate 58, the training accuracy is:- 0.9655915747286126
# at random sate 58, the testing accuracy is:- 0.8333509919085699
#
#
# at random sate 59, the training accuracy is:- 0.963851096372417
# at random sate 59, the testing accuracy is:- 0.8071392690992225
#
#
# at random sate 60, the training accuracy is:- 0.9658891938847588
# at random sate 60, the testing accuracy is:- 0.8269851462465185
#
#
# at random sate 61, the training accuracy is:- 0.9678593279717962
# at random sate 61, the testing accuracy is:- 0.8567937343512007
#
#
# at random sate 62, the training accuracy is:- 0.970097832177709
# at random sate 62, the testing accuracy is:- 0.7445282427914137
# at random sate 63, the training accuracy is:- 0.9649937721713241
# at random sate 63, the testing accuracy is:- 0.8153148027111147
#
#
# at random sate 64, the training accuracy is:- 0.9679538035582544
# at random sate 64, the testing accuracy is:- 0.8174653579433515
#
#
# at random sate 65, the training accuracy is:- 0.9656282314399366
# at random sate 65, the testing accuracy is:- 0.8193192887955085
#
#
# at random sate 66, the training accuracy is:- 0.970929357235352
# at random sate 66, the testing accuracy is:- 0.7702998303653287
#
#
# at random sate 67, the training accuracy is:- 0.9712092373755784
# at random sate 67, the testing accuracy is:- 0.8141680909328549
#
#
# at random sate 68, the training accuracy is:- 0.9693968963408597
# at random sate 68, the testing accuracy is:- 0.8242756997258174
#
#
# at random sate 69, the training accuracy is:- 0.9671021845554781
# at random sate 69, the testing accuracy is:- 0.8638305026692845
#
#
# at random sate 70, the training accuracy is:- 0.9701525767608291
# at random sate 70, the testing accuracy is:- 0.8464929529497731
#
#
# at random sate 71, the training accuracy is:- 0.9701543139913926
# at random sate 71, the testing accuracy is:- 0.8522635539073158
#
#
# at random sate 72, the training accuracy is:- 0.9764063373568205
# at random sate 72, the testing accuracy is:- 0.7323558746435297
#
#
# at random sate 73, the training accuracy is:- 0.9706296722535175
# at random sate 73, the testing accuracy is:- 0.7932709400225689
#
#
# at random sate 74, the training accuracy is:- 0.969728424150923
# at random sate 74, the testing accuracy is:- 0.7876596614509612
#
#
# at random sate 75, the training accuracy is:- 0.9721177589035962
# at random sate 75, the testing accuracy is:- 0.7692882768546498
#
#
# at random sate 76, the training accuracy is:- 0.9644068105450634
# at random sate 76, the testing accuracy is:- 0.8680473761547048
#
#
# at random sate 77, the training accuracy is:- 0.9731793445912263
# at random sate 77, the testing accuracy is:- 0.7813552195484373
#
#
# at random sate 78, the training accuracy is:- 0.966855102807554
# at random sate 78, the testing accuracy is:- 0.7780598992457097
#
#
# at random sate 79, the training accuracy is:- 0.9709045359656949
# at random sate 79, the testing accuracy is:- 0.6621920422216212
#
#
# at random sate 80, the training accuracy is:- 0.9678742263681619
# at random sate 80, the testing accuracy is:- 0.7898322381989655
#
#
# at random sate 81, the training accuracy is:- 0.9633668951689318
# at random sate 81, the testing accuracy is:- 0.7018163600354017
#
#
# at random sate 82, the training accuracy is:- 0.9755988636290001
# at random sate 82, the testing accuracy is:- 0.7742808339393804
#
#
# at random sate 83, the training accuracy is:- 0.9714816126482182
# at random sate 83, the testing accuracy is:- 0.8231910473906533
#
#
# at random sate 84, the training accuracy is:- 0.9698973354385693
# at random sate 84, the testing accuracy is:- 0.8400606845536189
#
#
# at random sate 85, the training accuracy is:- 0.9717060132600371
# at random sate 85, the testing accuracy is:- 0.7897321852068955
#
#
# at random sate 86, the training accuracy is:- 0.9684381203595275
# at random sate 86, the testing accuracy is:- 0.821273958143802
#
#
# at random sate 87, the training accuracy is:- 0.9676499528665529
# at random sate 87, the testing accuracy is:- 0.8322994636034058
#
#
# at random sate 88, the training accuracy is:- 0.9664472486459196
# at random sate 88, the testing accuracy is:- 0.8407601057612603
#
#
# at random sate 89, the training accuracy is:- 0.9635864451266913
# at random sate 89, the testing accuracy is:- 0.8684351118087595
#
#
# at random sate 90, the training accuracy is:- 0.9602579673098836
# at random sate 90, the testing accuracy is:- 0.7748563230843868
#
#
# at random sate 91, the training accuracy is:- 0.9705486693906952
# at random sate 91, the testing accuracy is:- 0.7792476203685634
#
#
# at random sate 92, the training accuracy is:- 0.9637881787312629
# at random sate 92, the testing accuracy is:- 0.832736071629912
#
#
# at random sate 93, the training accuracy is:- 0.9679250389533938
# at random sate 93, the testing accuracy is:- 0.8401480843846668
#
#
# at random sate 94, the training accuracy is:- 0.9691695247333786
# at random sate 94, the testing accuracy is:- 0.8235657580237766
#
#
# at random sate 95, the training accuracy is:- 0.96938370130791
# at random sate 95, the testing accuracy is:- 0.8352947413985174
#
#
# at random sate 96, the training accuracy is:- 0.9740468642525432
# at random sate 96, the testing accuracy is:- 0.8068460939265264
#
#
# at random sate 97, the training accuracy is:- 0.9695809548012136
# at random sate 97, the testing accuracy is:- 0.7995704092963075
#
#
# at random sate 98, the training accuracy is:- 0.9655012847757546
# at random sate 98, the testing accuracy is:- 0.8206033171882685
#
#
# at random sate 99, the training accuracy is:- 0.9687414254325902
# at random sate 99, the testing accuracy is:- 0.8419412648495881

# %%
#Lets split for train and test data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state= 10)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (882, 14)
# (379, 14)
# (882,)
# (379,)

# %% [markdown]
# # Now lets build the model for Flight Price Prediction

# %%
R2Score=[]
Acc=[]

# %%
def print_score(model,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=model.predict(x_train)
        print("Train Report:",r2_score(y_train,y_pred))
    elif train==False:
        pred=model.predict(x_test)
        print("Test Report:",r2_score(y_test,pred))
        print("RMSE:",np.sqrt(mean_squared_error(y_test,pred)))
        print("MAE:",mean_absolute_error(y_test,pred))
        print("MSE:",mean_squared_error(y_test,pred))
        R2Score.append(r2_score(y_test,pred))

# %%
#Below is a function to find the accuracy of each model on the basis of K-fold cross validation.

from sklearn.model_selection import cross_val_score
def model_accuracy(model,X_train=x_train,y_train=y_train):
    accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv =2)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
    Acc.append(accuracies.mean()*100)

# %%
# Model no.1
from sklearn.ensemble import RandomForestRegressor

rand_regressor= RandomForestRegressor()
rand_regressor.fit(x_train,y_train)

print_score(rand_regressor,x_train,x_test,y_train,y_test,train=True)
print_score(rand_regressor,x_train,x_test,y_train,y_test,train=False)
model_accuracy(rand_regressor)
# Out:
# Train Report: 0.9691487695822859
# Test Report: 0.8751568104873557
# RMSE: 0.2894882380572576
# MAE: 0.2004730971398237
# MSE: 0.08380343997349543
# Accuracy: 68.78 %
# Standard Deviation: 3.28 %

# %%
# Model no.2
from xgboost import XGBRegressor

xgb=XGBRegressor()
xgb.fit(x_train,y_train)

print_score(xgb,x_train,x_test,y_train,y_test,train=True)
print_score(xgb,x_train,x_test,y_train,y_test,train=False)
model_accuracy(xgb)
# Out:
# Train Report: 0.9957149112813691
# Test Report: 0.8553734350957934
# RMSE: 0.3115821220639864
# MAE: 0.20732251396863638
# MSE: 0.09708341878989693
# Accuracy: 66.69 %
# Standard Deviation: 4.61 %

# %%
#Model no.3
from sklearn.ensemble import GradientBoostingRegressor

gbdt=GradientBoostingRegressor()

gbdt.fit(x_train,y_train)

print_score(gbdt,x_train,x_test,y_train,y_test,train=True)
print_score(gbdt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(gbdt)
# Out:
# Train Report: 0.8626587679259862
# Test Report: 0.8261378243916362
# RMSE: 0.341626105533043
# MAE: 0.2592900291667444
# MSE: 0.11670839598167386
# Accuracy: 69.57 %
# Standard Deviation: 0.73 %

# %%
#Model no.4
from sklearn.ensemble import BaggingRegressor

bb=BaggingRegressor()

bb.fit(x_train,y_train)

print_score(bb,x_train,x_test,y_train,y_test,train=True)
print_score(bb,x_train,x_test,y_train,y_test,train=False)
model_accuracy(bb)
# Out:
# Train Report: 0.9460282186327424
# Test Report: 0.8402493153519478
# RMSE: 0.3274687479034962
# MAE: 0.223180213863351
# MSE: 0.10723578085348356
# Accuracy: 65.87 %
# Standard Deviation: 4.37 %

# %%
# Model no.5
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()

ada.fit(x_train,y_train)

print_score(ada,x_train,x_test,y_train,y_test,train=True)
print_score(ada,x_train,x_test,y_train,y_test,train=False)
model_accuracy(ada)
# Out:
# Train Report: 0.7237045630422209
# Test Report: 0.7012990253372076
# RMSE: 0.4477821889869735
# MAE: 0.34583135896797146
# MSE: 0.2005088887739656
# Accuracy: 57.08 %
# Standard Deviation: 0.12 %

# %%
#Model no.6
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()

dt.fit(x_train,y_train)

print_score(dt,x_train,x_test,y_train,y_test,train=True)
print_score(dt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(dt)
# Out:
# Train Report: 0.9960515702874893
# Test Report: 0.7275067736638644
# RMSE: 0.4276872965143996
# MAE: 0.22632669684370058
# MSE: 0.18291642359979593
# Accuracy: 27.34 %
# Standard Deviation: 1.09 %

# %%
final=pd.DataFrame({'R2Score':R2Score,'Acc':Acc})
final
# Out:
#     R2Score        Acc
# 0  0.875157  68.775559
# 1  0.855373  66.689220
# 2  0.826138  69.573593
# 3  0.840249  65.874160
# 4  0.701299  57.075613
# 5  0.727507  27.344613

# %% [markdown]
# # Selecting GradiantBoostingRegressor with 69.57% accuracy.

# %% [markdown]
# # HyperTunning Parameter

# %%
# Hyper tuning by using GridSearchCV
from sklearn.model_selection import GridSearchCV

para={'max_features':range(0,12,2),'min_samples_split':[4,5,9],'n_estimators':range(10,100,10),'max_depth':range(2,10,2)}
grid=GridSearchCV(estimator=gbdt, param_grid=para,cv=2)
grid.fit(x_train,y_train)

grid.best_params_
# Out:
# {'max_depth': 6, 'max_features': 6, 'min_samples_split': 4, 'n_estimators': 90}

# %%
#Model no.3
from sklearn.ensemble import GradientBoostingRegressor

gbdt=GradientBoostingRegressor(max_depth=6, max_features= 6, min_samples_split= 4, n_estimators= 90)

gbdt.fit(x_train,y_train)

print_score(gbdt,x_train,x_test,y_train,y_test,train=True)
print_score(gbdt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(gbdt)
# Out:
# Train Report: 0.9808315723538248
# Test Report: 0.8800250956334261
# RMSE: 0.283787787033619
# MAE: 0.2047259528262078
# MSE: 0.08053550806943868
# Accuracy: 75.98 %
# Standard Deviation: 0.79 %

# %%
# Hyper tuning by using RandomizedSearchCV With Bagging
from sklearn.model_selection import RandomizedSearchCV

para={'max_features':range(0,12,2),'min_samples_split':[4,5,9],'n_estimators':range(10,100,10),'max_depth':range(2,10,2)}
rand=RandomizedSearchCV(estimator=gbdt, cv=10,param_distributions=para)
rand.fit(x_train,y_train)

rand.best_params_
# Out:
# {'n_estimators': 50, 'min_samples_split': 4, 'max_features': 8, 'max_depth': 8}

# %%
#Model no.3
from sklearn.ensemble import GradientBoostingRegressor

gbdt=GradientBoostingRegressor(max_depth=8, max_features= 8, min_samples_split= 4, n_estimators= 50, alpha=0.0001)

gbdt.fit(x_train,y_train)

print_score(gbdt,x_train,x_test,y_train,y_test,train=True)
print_score(gbdt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(gbdt)
# Out:
# Train Report: 0.9892498174062029
# Test Report: 0.8864694335975525
# RMSE: 0.2760608987058556
# MAE: 0.1847805707272987
# MSE: 0.07620961979428467
# Accuracy: 74.73 %
# Standard Deviation: 0.71 %

# %% [markdown]
# # After hypertuning i m selecting GradientBoostingRegressor with GridSearchCV with kfold cross validation with accuracy 75.98 %.

# %%
#save model
import pickle
Filename='Finalized_model_Flight_PriceGBDT.pickle'
pickle.dump(gbdt,open(Filename,'wb'))

# %%
#serialization using joblib
import joblib
joblib.dump(gbdt,'Finalized_model_Flight_PriceGBDT.obj')
# Out:
# ['Finalized_model_Flight_PriceGBDT.obj']

# %%
F_P= joblib.load('Finalized_model_Flight_PriceGBDT.obj')

# %%
s_pred = F_P.predict(x_test)

# %%
r2_score(y_test,s_pred)
# Out:
# 0.8864694335975525

# %%
#lets plot y_test vs predicted 

plt.figure(figsize=(6,4))
plt.scatter(x = y_test,y = s_pred,color = 'r')
plt.plot(y_test,y_test,color = 'b')
plt.xlabel('Actual charges')
plt.ylabel('Predicted charges')
plt.title('Gradient Boosting Regressor')
plt.show()

# %%
#lets make a dataframe of actual answers vs predicted answers
conclusion = pd.DataFrame((F_P.predict(x_test)[:],y_test[:]),index= ['Predicted','Actual'])
conclusion
# Out:
#                 0         1         2         3         4         5    \
# Predicted -0.911360 -0.652366  2.037716 -0.085681 -0.570564 -0.476368
# Actual    -0.973475 -0.492669  2.060329 -0.176418 -0.340880 -0.765127
#
#                 6         7         8         9    ...       369       370  \
# Predicted  0.938375  0.285355 -0.922502  0.856676  ... -0.249599 -0.179676
# Actual     0.576640  0.116807 -0.592731  1.090173  ... -0.185532 -0.176418
#
#                 371       372       373       374       375       376  \
# Predicted  0.677121  0.375836  0.692262 -0.375569 -0.280921  0.451857
# Actual     0.805149  0.530191  0.605547 -0.185532 -0.227419  0.425809
#
#                 377       378
# Predicted  1.998318 -0.917755
# Actual     2.060329 -0.541953
#
# [2 rows x 379 columns]
